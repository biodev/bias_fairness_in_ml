# %%
from meps_model import WeightedLitDNN

from nvflare.app_common.workflows.fedavg import FedAvg
from nvflare.app_opt.pt.job_config.base_fed_job import BaseFedJob
from nvflare.job_config.script_runner import ScriptRunner

# %%
job = BaseFedJob(
    name="meps_lightning_fedavg",
    initial_model=WeightedLitDNN(),
    key_metric="val_loss"
)

# %%
n_clients = 3

controller = FedAvg(
    num_clients=n_clients,
    num_rounds=5,
)
job.to(controller, "server")

# %%
for i in range(n_clients):
    runner = ScriptRunner(
        script="meps_nvflare.py", script_args=f"--batch_size 256 --local_epochs 100 --weights --dataset_path /data/shared/analysis/bias_fairness/for_fl/site_{i+1}"
    )
    job.to(runner, f"site_{i+1}")

# %%
job.simulator_run("/data/shared/analysis/bias_fairness/nvflare_weighted_wkdir")
# Out:
# 2025-07-13 10:18:19,690 - SimulatorRunner - INFO - Create the Simulator Server.
# 2025-07-13 10:18:19,695 - CoreCell - INFO - server: creating listener on tcp://0:48345
# 2025-07-13 10:18:19,761 - CoreCell - INFO - server: created backbone external listener for tcp://0:48345
# 2025-07-13 10:18:19,761 - ConnectorManager - INFO - 594320: Try start_listener Listener resources: {'secure': False, 'host': 'localhost'}
# 2025-07-13 10:18:19,765 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connector [CH00002 PASSIVE tcp://0:30075] is starting
# 2025-07-13 10:18:20,267 - CoreCell - INFO - server: created backbone internal listener for tcp://localhost:30075
# 2025-07-13 10:18:20,267 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connector [CH00001 PASSIVE tcp://0:48345] is starting
# 2025-07-13 10:18:20,270 - SimulatorServer - INFO - max_reg_duration=60.0
# 2025-07-13 10:18:20,559 - nvflare.fuel.hci.server.hci - INFO - Starting Admin Server localhost on Port 51323
# 2025-07-13 10:18:20,559 - SimulatorRunner - INFO - Deploy the Apps.
# 2025-07-13 10:18:20,587 - SimulatorRunner - INFO - Create the simulate clients.
# 2025-07-13 10:18:20,598 - Communicator - INFO - Trying to register with server ...
# 2025-07-13 10:18:20,600 - ClientManager - INFO - authenticated client site_1
# 2025-07-13 10:18:20,601 - ClientManager - INFO - Client: New client site_1@137.53.221.88 joined. Sent token: 290fd01d-cfcc-46d2-94b6-e1a675d79981.  Total clients: 1
# 2025-07-13 10:18:20,602 - Communicator - INFO - register RC: ok
# 2025-07-13 10:18:20,602 - FederatedClient - INFO - Successfully registered client:site_1 for project simulator_server. Token:290fd01d-cfcc-46d2-94b6-e1a675d79981 SSID:
# 2025-07-13 10:18:20,605 - Communicator - INFO - Trying to register with server ...
# 2025-07-13 10:18:20,606 - ClientManager - INFO - authenticated client site_2
# 2025-07-13 10:18:20,607 - ClientManager - INFO - Client: New client site_2@137.53.221.88 joined. Sent token: f76f2465-59d7-4a62-802f-cfbe7885070e.  Total clients: 2
# 2025-07-13 10:18:20,607 - Communicator - INFO - register RC: ok
# 2025-07-13 10:18:20,608 - FederatedClient - INFO - Successfully registered client:site_2 for project simulator_server. Token:f76f2465-59d7-4a62-802f-cfbe7885070e SSID:
# 2025-07-13 10:18:20,611 - Communicator - INFO - Trying to register with server ...
# 2025-07-13 10:18:20,612 - ClientManager - INFO - authenticated client site_3
# 2025-07-13 10:18:20,613 - ClientManager - INFO - Client: New client site_3@137.53.221.88 joined. Sent token: e5a88aee-88b7-4180-bd9e-6fd2ebc18f66.  Total clients: 3
# 2025-07-13 10:18:20,614 - Communicator - INFO - register RC: ok
# 2025-07-13 10:18:20,614 - FederatedClient - INFO - Successfully registered client:site_3 for project simulator_server. Token:e5a88aee-88b7-4180-bd9e-6fd2ebc18f66 SSID:
# 2025-07-13 10:18:20,614 - SimulatorRunner - INFO - Set the client status ready.
# 2025-07-13 10:18:20,615 - SimulatorRunner - INFO - Deploy and start the Server App.
# 2025-07-13 10:18:20,618 - Cell - INFO - Register blob CB for channel='server_command', topic='*'
# 2025-07-13 10:18:20,618 - Cell - INFO - Register blob CB for channel='aux_communication', topic='*'
# 2025-07-13 10:18:20,619 - ServerCommandAgent - INFO - ServerCommandAgent cell register_request_cb: server.simulate_job
# 2025-07-13 10:18:20,642 - IntimeModelSelector - INFO - model selection weights control: {}
# 2025-07-13 10:18:25,439 - AuxRunner - INFO - registered aux handler for topic __sync_runner__
# 2025-07-13 10:18:25,439 - AuxRunner - INFO - registered aux handler for topic __job_heartbeat__
# 2025-07-13 10:18:25,439 - AuxRunner - INFO - registered aux handler for topic __task_check__
# 2025-07-13 10:18:25,440 - AuxRunner - INFO - registered aux handler for topic RM.RELIABLE_REQUEST
# 2025-07-13 10:18:25,441 - AuxRunner - INFO - registered aux handler for topic RM.RELIABLE_REPLY
# 2025-07-13 10:18:25,441 - ReliableMessage - INFO - enabled reliable message: max_request_workers=20 query_interval=2.0
# 2025-07-13 10:18:25,441 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job]: Server runner starting ...
# 2025-07-13 10:18:25,442 - TBAnalyticsReceiver - INFO - [identity=simulator_server, run=simulate_job]: Tensorboard records can be found in /data/shared/analysis/bias_fairness/nvflare_weighted_wkdir/server/simulate_job/tb_events you can view it using `tensorboard --logdir=/data/shared/analysis/bias_fairness/nvflare_weighted_wkdir/server/simulate_job/tb_events`
# 2025-07-13 10:18:25,442 - AuxRunner - INFO - registered aux handler for topic fed.event
# 2025-07-13 10:18:25,442 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job]: starting workflow controller (<class 'nvflare.app_common.workflows.fedavg.FedAvg'>) ...
# 2025-07-13 10:18:25,443 - FedAvg - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: Initializing BaseModelController workflow.
# 2025-07-13 10:18:25,443 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: Workflow controller (<class 'nvflare.app_common.workflows.fedavg.FedAvg'>) started
# 2025-07-13 10:18:25,443 - FedAvg - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: Beginning model controller run.
# 2025-07-13 10:18:25,444 - FedAvg - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: Start FedAvg.
# 2025-07-13 10:18:25,444 - FedAvg - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: loading initial model from persistor
# 2025-07-13 10:18:25,444 - PTFileModelPersistor - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: Both source_ckpt_file_full_name and ckpt_preload_path are not provided. Using the default model weights initialized on the persistor side.
# 2025-07-13 10:18:25,444 - FedAvg - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: Round 0 started.
# 2025-07-13 10:18:25,445 - FedAvg - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: Sampled clients: ['site_1', 'site_2', 'site_3']
# 2025-07-13 10:18:25,445 - FedAvg - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: Sending task train to ['site_1', 'site_2', 'site_3']
# 2025-07-13 10:18:25,445 - WFCommServer - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: scheduled task train
# 2025-07-13 10:18:25,798 - SimulatorClientRunner - INFO - Start the clients run simulation.
# 2025-07-13 10:18:26,800 - SimulatorClientRunner - INFO - Simulate Run client: site_1 on GPU group: None
# 2025-07-13 10:18:26,801 - SimulatorClientRunner - INFO - Simulate Run client: site_2 on GPU group: None
# 2025-07-13 10:18:26,826 - SimulatorClientRunner - INFO - Simulate Run client: site_3 on GPU group: None
# 2025-07-13 10:18:27,868 - ClientTaskWorker - INFO - ClientTaskWorker started to run
# 2025-07-13 10:18:27,868 - ClientTaskWorker - INFO - ClientTaskWorker started to run
# 2025-07-13 10:18:27,882 - ClientTaskWorker - INFO - ClientTaskWorker started to run
# 2025-07-13 10:18:27,936 - CoreCell - INFO - site_2.simulate_job: created backbone external connector to tcp://localhost:48345
# 2025-07-13 10:18:27,936 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connector [CH00001 ACTIVE tcp://localhost:48345] is starting
# 2025-07-13 10:18:27,937 - CoreCell - INFO - site_1.simulate_job: created backbone external connector to tcp://localhost:48345
# 2025-07-13 10:18:27,937 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connector [CH00001 ACTIVE tcp://localhost:48345] is starting
# 2025-07-13 10:18:27,938 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connection [CN00002 127.0.0.1:53700 => 127.0.0.1:48345] is created: PID: 594386
# 2025-07-13 10:18:27,938 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connection [CN00002 127.0.0.1:53706 => 127.0.0.1:48345] is created: PID: 594385
# 2025-07-13 10:18:27,939 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connection [CN00006 127.0.0.1:48345 <= 127.0.0.1:53700] is created: PID: 594320
# 2025-07-13 10:18:27,939 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connection [CN00007 127.0.0.1:48345 <= 127.0.0.1:53706] is created: PID: 594320
# 2025-07-13 10:18:27,950 - CoreCell - INFO - site_3.simulate_job: created backbone external connector to tcp://localhost:48345
# 2025-07-13 10:18:27,951 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connector [CH00001 ACTIVE tcp://localhost:48345] is starting
# 2025-07-13 10:18:27,951 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connection [CN00002 127.0.0.1:53716 => 127.0.0.1:48345] is created: PID: 594387
# 2025-07-13 10:18:27,952 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connection [CN00008 127.0.0.1:48345 <= 127.0.0.1:53716] is created: PID: 594320
# 2025-07-13 10:18:30,741 - AuxRunner - INFO - registered aux handler for topic __end_run__
# 2025-07-13 10:18:30,741 - AuxRunner - INFO - registered aux handler for topic __do_task__
# 2025-07-13 10:18:30,742 - Cell - INFO - Register blob CB for channel='aux_communication', topic='*'
# 2025-07-13 10:18:30,773 - AuxRunner - INFO - registered aux handler for topic __end_run__
# 2025-07-13 10:18:30,773 - AuxRunner - INFO - registered aux handler for topic __do_task__
# 2025-07-13 10:18:30,773 - Cell - INFO - Register blob CB for channel='aux_communication', topic='*'
# 2025-07-13 10:18:31,055 - AuxRunner - INFO - registered aux handler for topic __end_run__
# 2025-07-13 10:18:31,055 - AuxRunner - INFO - registered aux handler for topic __do_task__
# 2025-07-13 10:18:31,056 - Cell - INFO - Register blob CB for channel='aux_communication', topic='*'
# 2025-07-13 10:18:31,247 - Cell - INFO - broadcast: channel='aux_communication', topic='__sync_runner__', targets=['server.simulate_job'], timeout=2.0
# 2025-07-13 10:18:31,262 - ClientRunner - INFO - [identity=site_1, run=simulate_job]: synced to Server Runner in 0.5156950950622559 seconds
# 2025-07-13 10:18:31,263 - AuxRunner - INFO - registered aux handler for topic RM.RELIABLE_REQUEST
# 2025-07-13 10:18:31,263 - AuxRunner - INFO - registered aux handler for topic RM.RELIABLE_REPLY
# 2025-07-13 10:18:31,264 - ReliableMessage - INFO - enabled reliable message: max_request_workers=20 query_interval=2.0
# 2025-07-13 10:18:31,266 - TaskScriptRunner - INFO - start task run() with full path: /data/shared/analysis/bias_fairness/nvflare_weighted_wkdir/site_1/simulate_job/app_site_1/custom/meps_nvflare.py
# 2025-07-13 10:18:31,266 - AuxRunner - INFO - registered aux handler for topic fed.event
# 2025-07-13 10:18:31,267 - ClientRunner - INFO - [identity=site_1, run=simulate_job]: client runner started
# 2025-07-13 10:18:31,267 - ClientTaskWorker - INFO - Initialize ClientRunner for client: site_1
# 2025-07-13 10:18:31,278 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_1, peer_run=simulate_job, task_name=train, task_id=77f793fe-0a3e-4dbb-992a-9bf646500921]: assigned task to client site_1: name=train, id=77f793fe-0a3e-4dbb-992a-9bf646500921
# 2025-07-13 10:18:31,279 - Cell - INFO - broadcast: channel='aux_communication', topic='__sync_runner__', targets=['server.simulate_job'], timeout=2.0
# 2025-07-13 10:18:31,280 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_1, peer_run=simulate_job, task_name=train, task_id=77f793fe-0a3e-4dbb-992a-9bf646500921]: sent task assignment to client. client_name:site_1 task_id:77f793fe-0a3e-4dbb-992a-9bf646500921
# 2025-07-13 10:18:31,280 - GetTaskCommand - INFO - return task to client.  client_name: site_1  task_name: train   task_id: 77f793fe-0a3e-4dbb-992a-9bf646500921  sharable_header_task_id: 77f793fe-0a3e-4dbb-992a-9bf646500921
# 2025-07-13 10:18:31,291 - ClientRunner - INFO - [identity=site_2, run=simulate_job]: synced to Server Runner in 0.5132956504821777 seconds
# 2025-07-13 10:18:31,292 - AuxRunner - INFO - registered aux handler for topic RM.RELIABLE_REQUEST
# 2025-07-13 10:18:31,292 - AuxRunner - INFO - registered aux handler for topic RM.RELIABLE_REPLY
# 2025-07-13 10:18:31,293 - ReliableMessage - INFO - enabled reliable message: max_request_workers=20 query_interval=2.0
# 2025-07-13 10:18:31,293 - Communicator - INFO - Received from simulator_server server. getTask: train size: 36.2KB (36205 Bytes) time: 0.024800 seconds
# 2025-07-13 10:18:31,294 - TaskScriptRunner - INFO - start task run() with full path: /data/shared/analysis/bias_fairness/nvflare_weighted_wkdir/site_2/simulate_job/app_site_2/custom/meps_nvflare.py
# 2025-07-13 10:18:31,295 - AuxRunner - INFO - registered aux handler for topic fed.event
# 2025-07-13 10:18:31,295 - FederatedClient - INFO - pull_task completed. Task name:train Status:True
# 2025-07-13 10:18:31,295 - ClientRunner - INFO - [identity=site_2, run=simulate_job]: client runner started
# 2025-07-13 10:18:31,296 - ClientRunner - INFO - [identity=site_1, run=simulate_job, peer=simulator_server, peer_run=simulate_job]: got task assignment: name=train, id=77f793fe-0a3e-4dbb-992a-9bf646500921
# 2025-07-13 10:18:31,296 - ClientTaskWorker - INFO - Initialize ClientRunner for client: site_2
# 2025-07-13 10:18:31,299 - ClientRunner - INFO - [identity=site_1, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=77f793fe-0a3e-4dbb-992a-9bf646500921]: invoking task executor PTInProcessClientAPIExecutor
# 2025-07-13 10:18:31,299 - PTInProcessClientAPIExecutor - INFO - [identity=site_1, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=77f793fe-0a3e-4dbb-992a-9bf646500921]: execute for task (train)
# 2025-07-13 10:18:31,301 - PTInProcessClientAPIExecutor - INFO - [identity=site_1, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=77f793fe-0a3e-4dbb-992a-9bf646500921]: send data to peer
# 2025-07-13 10:18:31,302 - PTInProcessClientAPIExecutor - INFO - [identity=site_1, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=77f793fe-0a3e-4dbb-992a-9bf646500921]: sending payload to peer
# 2025-07-13 10:18:31,305 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_2, peer_run=simulate_job, task_name=train, task_id=a0b953d8-444c-47b3-a101-934052e2473d]: assigned task to client site_2: name=train, id=a0b953d8-444c-47b3-a101-934052e2473d
# 2025-07-13 10:18:31,306 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_2, peer_run=simulate_job, task_name=train, task_id=a0b953d8-444c-47b3-a101-934052e2473d]: sent task assignment to client. client_name:site_2 task_id:a0b953d8-444c-47b3-a101-934052e2473d
# 2025-07-13 10:18:31,307 - GetTaskCommand - INFO - return task to client.  client_name: site_2  task_name: train   task_id: a0b953d8-444c-47b3-a101-934052e2473d  sharable_header_task_id: a0b953d8-444c-47b3-a101-934052e2473d
# 2025-07-13 10:18:31,307 - PTInProcessClientAPIExecutor - INFO - [identity=site_1, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=77f793fe-0a3e-4dbb-992a-9bf646500921]: Waiting for result from peer
# 2025-07-13 10:18:31,328 - Communicator - INFO - Received from simulator_server server. getTask: train size: 36.2KB (36205 Bytes) time: 0.030318 seconds
# 2025-07-13 10:18:31,330 - FederatedClient - INFO - pull_task completed. Task name:train Status:True
# 2025-07-13 10:18:31,332 - ClientRunner - INFO - [identity=site_2, run=simulate_job, peer=simulator_server, peer_run=simulate_job]: got task assignment: name=train, id=a0b953d8-444c-47b3-a101-934052e2473d
# 2025-07-13 10:18:31,334 - ClientRunner - INFO - [identity=site_2, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=a0b953d8-444c-47b3-a101-934052e2473d]: invoking task executor PTInProcessClientAPIExecutor
# 2025-07-13 10:18:31,335 - PTInProcessClientAPIExecutor - INFO - [identity=site_2, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=a0b953d8-444c-47b3-a101-934052e2473d]: execute for task (train)
# 2025-07-13 10:18:31,337 - PTInProcessClientAPIExecutor - INFO - [identity=site_2, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=a0b953d8-444c-47b3-a101-934052e2473d]: send data to peer
# 2025-07-13 10:18:31,337 - PTInProcessClientAPIExecutor - INFO - [identity=site_2, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=a0b953d8-444c-47b3-a101-934052e2473d]: sending payload to peer
# 2025-07-13 10:18:31,339 - PTInProcessClientAPIExecutor - INFO - [identity=site_2, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=a0b953d8-444c-47b3-a101-934052e2473d]: Waiting for result from peer
# 2025-07-13 10:18:31,562 - Cell - INFO - broadcast: channel='aux_communication', topic='__sync_runner__', targets=['server.simulate_job'], timeout=2.0
# 2025-07-13 10:18:31,574 - ClientRunner - INFO - [identity=site_3, run=simulate_job]: synced to Server Runner in 0.5126368999481201 seconds
# 2025-07-13 10:18:31,575 - AuxRunner - INFO - registered aux handler for topic RM.RELIABLE_REQUEST
# 2025-07-13 10:18:31,575 - AuxRunner - INFO - registered aux handler for topic RM.RELIABLE_REPLY
# 2025-07-13 10:18:31,576 - ReliableMessage - INFO - enabled reliable message: max_request_workers=20 query_interval=2.0
# 2025-07-13 10:18:31,577 - TaskScriptRunner - INFO - start task run() with full path: /data/shared/analysis/bias_fairness/nvflare_weighted_wkdir/site_3/simulate_job/app_site_3/custom/meps_nvflare.py
# 2025-07-13 10:18:31,578 - AuxRunner - INFO - registered aux handler for topic fed.event
# 2025-07-13 10:18:31,579 - ClientRunner - INFO - [identity=site_3, run=simulate_job]: client runner started
# 2025-07-13 10:18:31,579 - ClientTaskWorker - INFO - Initialize ClientRunner for client: site_3
# 2025-07-13 10:18:31,590 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_3, peer_run=simulate_job, task_name=train, task_id=94730f40-ddc2-4a3b-8fbc-8e1b4954529c]: assigned task to client site_3: name=train, id=94730f40-ddc2-4a3b-8fbc-8e1b4954529c
# 2025-07-13 10:18:31,591 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_3, peer_run=simulate_job, task_name=train, task_id=94730f40-ddc2-4a3b-8fbc-8e1b4954529c]: sent task assignment to client. client_name:site_3 task_id:94730f40-ddc2-4a3b-8fbc-8e1b4954529c
# 2025-07-13 10:18:31,591 - GetTaskCommand - INFO - return task to client.  client_name: site_3  task_name: train   task_id: 94730f40-ddc2-4a3b-8fbc-8e1b4954529c  sharable_header_task_id: 94730f40-ddc2-4a3b-8fbc-8e1b4954529c
# 2025-07-13 10:18:31,603 - Communicator - INFO - Received from simulator_server server. getTask: train size: 36.2KB (36205 Bytes) time: 0.022486 seconds
# 2025-07-13 10:18:31,605 - FederatedClient - INFO - pull_task completed. Task name:train Status:True
# 2025-07-13 10:18:31,606 - ClientRunner - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job]: got task assignment: name=train, id=94730f40-ddc2-4a3b-8fbc-8e1b4954529c
# 2025-07-13 10:18:31,608 - ClientRunner - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=94730f40-ddc2-4a3b-8fbc-8e1b4954529c]: invoking task executor PTInProcessClientAPIExecutor
# 2025-07-13 10:18:31,609 - PTInProcessClientAPIExecutor - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=94730f40-ddc2-4a3b-8fbc-8e1b4954529c]: execute for task (train)
# 2025-07-13 10:18:31,611 - PTInProcessClientAPIExecutor - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=94730f40-ddc2-4a3b-8fbc-8e1b4954529c]: send data to peer
# 2025-07-13 10:18:31,612 - PTInProcessClientAPIExecutor - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=94730f40-ddc2-4a3b-8fbc-8e1b4954529c]: sending payload to peer
# 2025-07-13 10:18:31,615 - PTInProcessClientAPIExecutor - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=94730f40-ddc2-4a3b-8fbc-8e1b4954529c]: Waiting for result from peer
# 2025-07-13 10:18:34,008 - pytorch_lightning.utilities.rank_zero - INFO - You are using the plain ModelCheckpoint callback. Consider using LitModelCheckpoint which with seamless uploading to Model registry.
# 2025-07-13 10:18:34,022 - pytorch_lightning.utilities.rank_zero - INFO - GPU available: False, used: False
# 2025-07-13 10:18:34,023 - pytorch_lightning.utilities.rank_zero - INFO - TPU available: False, using: 0 TPU cores
# 2025-07-13 10:18:34,023 - pytorch_lightning.utilities.rank_zero - INFO - HPU available: False, using: 0 HPUs
# 2025-07-13 10:18:34,024 - nvflare.app_common.executors.task_script_runner - INFO -
# [Current Round=0, Site = site_1]
#
# 2025-07-13 10:18:34,024 - nvflare.app_common.executors.task_script_runner - INFO - --- validate global model ---
# 2025-07-13 10:18:34,029 - pytorch_lightning.utilities.rank_zero - INFO - You are using the plain ModelCheckpoint callback. Consider using LitModelCheckpoint which with seamless uploading to Model registry.
# 2025-07-13 10:18:34,042 - pytorch_lightning.utilities.rank_zero - INFO - GPU available: False, used: False
# 2025-07-13 10:18:34,043 - pytorch_lightning.utilities.rank_zero - INFO - TPU available: False, using: 0 TPU cores
# 2025-07-13 10:18:34,043 - pytorch_lightning.utilities.rank_zero - INFO - HPU available: False, using: 0 HPUs
# 2025-07-13 10:18:34,044 - nvflare.app_common.executors.task_script_runner - INFO -
# [Current Round=0, Site = site_2]
#
# 2025-07-13 10:18:34,044 - nvflare.app_common.executors.task_script_runner - INFO - --- validate global model ---
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 71.31it/s]
# 2025-07-13 10:18:34,136 - nvflare.app_common.executors.task_script_runner - INFO - ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#      Validate metric           DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         val_loss             1.17054283618927
# ──────────────────────────────────��─────────────────────────────────────────────────────────────────────────────────────
# 2025-07-13 10:18:34,138 - nvflare.app_common.executors.task_script_runner - INFO - --- train new model ---
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 67.65it/s]
# 2025-07-13 10:18:34,164 - nvflare.app_common.executors.task_script_runner - INFO - ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#      Validate metric           DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         val_loss            1.1911044120788574
# ──────────────────────────────────���─────────────────────────────────────────────────────────────────────────────────────
# 2025-07-13 10:18:34,165 - nvflare.app_common.executors.task_script_runner - INFO - --- train new model ---
# 2025-07-13 10:18:34,183 - lightning.pytorch.callbacks.model_summary - INFO -
#   | Name  | Type   | Params | Mode
# -----------------------------------------
# 0 | model | DeepNN | 7.6 K  | train
# -----------------------------------------
# 7.6 K     Trainable params
# 0         Non-trainable params
# 7.6 K     Total params
# 0.030     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking DataLoader 0:  50%|█████     | 1/2 [00:00<00:00, 221.90it/s]2025-07-13 10:18:34,205 - lightning.pytorch.callbacks.model_summary - INFO -
#   | Name  | Type   | Params | Mode
# -----------------------------------------
# 0 | model | DeepNN | 7.6 K  | train
# -----------------------------------------
# 7.6 K     Trainable params
# 0         Non-trainable params
# 7.6 K     Total params
# 0.030     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# INFO:
#   | Name  | Type   | Params | Mode
# -----------------------------------------
# 0 | model | DeepNN | 7.6 K  | train
# -----------------------------------------
# 7.6 K     Trainable params
# 0         Non-trainable params
# 7.6 K     Total params
# 0.030     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# INFO:
#   | Name  | Type   | Params | Mode
# -----------------------------------------
# 0 | model | DeepNN | 7.6 K  | train
# -----------------------------------------
# 7.6 K     Trainable params
# 0         Non-trainable params
# 7.6 K     Total params
# 0.030     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# Epoch 0:  47%|████▋     | 8/17 [00:00<00:00, 38.40it/s, v_num=0]2025-07-13 10:18:34,481 - pytorch_lightning.utilities.rank_zero - INFO - You are using the plain ModelCheckpoint callback. Consider using LitModelCheckpoint which with seamless uploading to Model registry.
# Epoch 0:  59%|█████▉    | 10/17 [00:00<00:00, 35.99it/s, v_num=0]2025-07-13 10:18:34,498 - pytorch_lightning.utilities.rank_zero - INFO - GPU available: False, used: False
# 2025-07-13 10:18:34,499 - pytorch_lightning.utilities.rank_zero - INFO - TPU available: False, using: 0 TPU cores
# 2025-07-13 10:18:34,499 - pytorch_lightning.utilities.rank_zero - INFO - HPU available: False, using: 0 HPUs
# 2025-07-13 10:18:34,501 - nvflare.app_common.executors.task_script_runner - INFO -
# [Current Round=0, Site = site_3]
#
# 2025-07-13 10:18:34,501 - nvflare.app_common.executors.task_script_runner - INFO - --- validate global model ---
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 40.09it/s]
# 2025-07-13 10:18:34,689 - nvflare.app_common.executors.task_script_runner - INFO - ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#      Validate metric           DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         val_loss            1.1665570735931396
# ──────────────────────────────────���─────────────────────────────────────────────────────────────────────────────────────
# 2025-07-13 10:18:34,691 - nvflare.app_common.executors.task_script_runner - INFO - --- train new model ---
# Epoch 0:  94%|█████████▍| 16/17 [00:00<00:00, 32.31it/s, v_num=0]2025-07-13 10:18:34,744 - lightning.pytorch.callbacks.model_summary - INFO -
#   | Name  | Type   | Params | Mode
# -----------------------------------------
# 0 | model | DeepNN | 7.6 K  | train
# -----------------------------------------
# 7.6 K     Trainable params
# 0         Non-trainable params
# 7.6 K     Total params
# 0.030     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 63.45it/s]
# Epoch 0: 100%|██████████| 17/17 [00:00<00:00, 29.33it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 0:   6%|▌         | 1/17 [00:00<00:00, 46.60it/s, v_num=0]A
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 136.32it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 154.85it/s]
# INFO:
#   | Name  | Type   | Params | Mode
# -----------------------------------------
# 0 | model | DeepNN | 7.6 K  | train
# -----------------------------------------
# 7.6 K     Trainable params
# 0         Non-trainable params
# 7.6 K     Total params
# 0.030     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# Epoch 0:  12%|█▏        | 2/17 [00:00<00:00, 45.66it/s, v_num=0]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 44.27it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 51.56it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 57.36it/s]
# Epoch 0: 100%|██████████| 17/17 [00:00<00:00, 27.41it/s, v_num=0]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 61.66it/s]
# Epoch 0: 100%|██████████| 17/17 [00:00<00:00, 23.52it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 1:  71%|███████   | 12/17 [00:00<00:00, 17.52it/s, v_num=0]3it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 42.95it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 59.17it/s]
# Epoch 1: 100%|██████████| 17/17 [00:01<00:00, 15.44it/s, v_num=0]
# Epoch 1:  47%|████▋     | 8/17 [00:00<00:00, 20.02it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 1:  82%|████████▏ | 14/17 [00:01<00:00, 12.15it/s, v_num=0]
# Epoch 1:  53%|█████▎    | 9/17 [00:00<00:00, 19.17it/s, v_num=0]7it/s]
# Epoch 1:  88%|████████▊ | 15/17 [00:01<00:00, 12.46it/s, v_num=0]it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 40.61it/s]
# Epoch 1: 100%|██████████| 17/17 [00:01<00:00, 13.17it/s, v_num=0]
# Epoch 1:  71%|███████   | 12/17 [00:00<00:00, 20.04it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 2:  12%|█▏        | 2/17 [00:00<00:00, 21.70it/s, v_num=0]A
# Epoch 2:  18%|█▊        | 3/17 [00:00<00:00, 22.30it/s, v_num=0]]it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 32.95it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 34.54it/s]
# Epoch 1: 100%|██████████| 17/17 [00:00<00:00, 19.70it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 2:  47%|████▋     | 8/17 [00:00<00:00, 21.64it/s, v_num=0]A
# Epoch 2:  53%|█████▎    | 9/17 [00:00<00:00, 22.35it/s, v_num=0]0it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 27.17it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 34.91it/s]
# Epoch 2: 100%|██████████| 17/17 [00:00<00:00, 20.31it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 2:  47%|████▋     | 8/17 [00:00<00:00, 19.01it/s, v_num=0]4it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 39.27it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 50.69it/s]
# Epoch 2: 100%|██████████| 17/17 [00:00<00:00, 20.75it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 2:  76%|███████▋  | 13/17 [00:01<00:00, 11.38it/s, v_num=0]it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 40.16it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 54.75it/s]
# Epoch 2: 100%|██████████| 17/17 [00:01<00:00, 12.29it/s, v_num=0]
# Epoch 3:  24%|██▎       | 4/17 [00:00<00:02,  5.86it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 3:  29%|██▉       | 5/17 [00:00<00:01,  6.74it/s, v_num=0]8it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 28.19it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 37.69it/s]
# Epoch 3: 100%|██████████| 17/17 [00:01<00:00, 11.88it/s, v_num=0]
# Epoch 3:  12%|█▏        | 2/17 [00:00<00:04,  3.11it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 3:  65%|██████▍   | 11/17 [00:01<00:00, 10.68it/s, v_num=0]
# Epoch 3:  18%|█▊        | 3/17 [00:00<00:03,  4.18it/s, v_num=0]0it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 27.93it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 36.84it/s]
# Epoch 3: 100%|██████████| 17/17 [00:01<00:00, 10.41it/s, v_num=0]
# Epoch 3:  47%|████▋     | 8/17 [00:01<00:01,  6.20it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 4:  29%|██▉       | 5/17 [00:00<00:01,  9.23it/s, v_num=0]A
# Epoch 4:  35%|███▌      | 6/17 [00:00<00:01,  9.74it/s, v_num=0]7it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 21.14it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 26.09it/s]
# Epoch 3: 100%|██████████| 17/17 [00:02<00:00,  8.27it/s, v_num=0]
# Epoch 4:  76%|███████▋  | 13/17 [00:01<00:00, 10.02it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]/s, v_num=0]
# Epoch 4:  29%|██▉       | 5/17 [00:00<00:01,  7.61it/s, v_num=0]A
# Epoch 4:  82%|████████▏ | 14/17 [00:01<00:00, 10.32it/s, v_num=0]it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 26.40it/s]
# Epoch 4:  35%|███▌      | 6/17 [00:00<00:01,  7.72it/s, v_num=0]7it/s]
# Epoch 4: 100%|██████████| 17/17 [00:01<00:00, 10.56it/s, v_num=0]
# Epoch 4:  12%|█▏        | 2/17 [00:00<00:01, 12.24it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 94.53it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 32.76it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 37.08it/s]
# Epoch 4: 100%|██████████| 17/17 [00:01<00:00, 10.13it/s, v_num=0]
# Epoch 5:  41%|████      | 7/17 [00:00<00:00, 11.35it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 4:  65%|██████▍   | 11/17 [00:00<00:00, 11.86it/s, v_num=0]it/s]
# Epoch 5:  47%|████▋     | 8/17 [00:00<00:00, 11.49it/s, v_num=0]8it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 37.11it/s]
# Epoch 4: 100%|██████████| 17/17 [00:01<00:00, 12.63it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 5:  82%|████████▏ | 14/17 [00:01<00:00, 12.64it/s, v_num=0]
# Epoch 5:  88%|████████▊ | 15/17 [00:01<00:00, 12.34it/s, v_num=0]it/s]
# Epoch 5:  35%|███▌      | 6/17 [00:00<00:00, 11.93it/s, v_num=0]3it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 21.82it/s]
# Epoch 5: 100%|██████████| 17/17 [00:01<00:00, 12.22it/s, v_num=0]
# Epoch 5:  47%|████▋     | 8/17 [00:00<00:00, 11.84it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 5:  12%|█▏        | 2/17 [00:00<00:01,  8.62it/s, v_num=0]A
# Epoch 5:  18%|█▊        | 3/17 [00:00<00:01,  9.35it/s, v_num=0]6it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 11.59it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 16.52it/s]
# Epoch 5: 100%|██████████| 17/17 [00:01<00:00, 11.00it/s, v_num=0]
# Epoch 5:  59%|█████▉    | 10/17 [00:01<00:00,  9.95it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 6:  41%|████      | 7/17 [00:00<00:00, 11.02it/s, v_num=0]A
# Epoch 5:  65%|██████▍   | 11/17 [00:01<00:00, 10.32it/s, v_num=0]it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 29.92it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 34.21it/s]
# Epoch 5: 100%|██████████| 17/17 [00:01<00:00, 11.58it/s, v_num=0]
# Epoch 6:  24%|██▎       | 4/17 [00:00<00:01, 11.96it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 6:  29%|██▉       | 5/17 [00:00<00:01, 11.66it/s, v_num=0]]it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 26.48it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 34.19it/s]
# Epoch 6: 100%|██████████| 17/17 [00:01<00:00, 13.00it/s, v_num=0]
# Epoch 6:  12%|█▏        | 2/17 [00:00<00:00, 15.63it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 6:  47%|████▋     | 8/17 [00:00<00:00, 12.63it/s, v_num=0]5it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 33.00it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 26.97it/s]
# Epoch 6: 100%|██████████| 17/17 [00:01<00:00, 11.10it/s, v_num=0]
# Epoch 6:  71%|███████   | 12/17 [00:01<00:00, 11.11it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 7:  53%|█████▎    | 9/17 [00:00<00:00, 10.91it/s, v_num=0]A
# Epoch 7:  59%|█████▉    | 10/17 [00:00<00:00, 11.16it/s, v_num=0]it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 23.40it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 29.12it/s]
# Epoch 6: 100%|██████████| 17/17 [00:01<00:00, 10.00it/s, v_num=0]
# 2025-07-13 10:18:44,499 - InProcessClientAPI - INFO - Try to send local model back to peer
# Epoch 6: 100%|██████████| 17/17 [00:01<00:00, 12.61it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 7:  82%|████████▏ | 14/17 [00:01<00:00, 12.59it/s, v_num=0]
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 97.17it/s]
# Epoch 7:  88%|████████▊ | 15/17 [00:01<00:00, 12.83it/s, v_num=0]it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 47.04it/s]
# Epoch 7: 100%|██████████| 17/17 [00:01<00:00, 13.60it/s, v_num=0]
# Epoch 7:   6%|▌         | 1/17 [00:00<00:00, 17.23it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 7:  12%|█▏        | 2/17 [00:00<00:00, 18.76it/s, v_num=0]3it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 43.37it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 54.43it/s]
# Epoch 8:   0%|          | 0/17 [00:00<?, ?it/s, v_num=0]2025-07-13 10:18:44,930 - ClientRunner - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=94730f40-ddc2-4a3b-8fbc-8e1b4954529c]: finished processing task
# 2025-07-13 10:18:44,931 - ClientRunner - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=94730f40-ddc2-4a3b-8fbc-8e1b4954529c]: try #1: sending task result to server
# 2025-07-13 10:18:44,932 - ClientRunner - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=94730f40-ddc2-4a3b-8fbc-8e1b4954529c]: checking task ...
# 2025-07-13 10:18:44,933 - Cell - INFO - broadcast: channel='aux_communication', topic='__task_check__', targets=['server.simulate_job'], timeout=5.0
# Epoch 7:  24%|██▎       | 4/17 [00:00<00:00, 18.89it/s, v_num=0]2025-07-13 10:18:44,950 - ClientRunner - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=94730f40-ddc2-4a3b-8fbc-8e1b4954529c]: start to send task result to server
# 2025-07-13 10:18:44,950 - FederatedClient - INFO - Starting to push execute result.
# Epoch 8:   6%|▌         | 1/17 [00:00<00:00, 16.35it/s, v_num=0]2025-07-13 10:18:44,964 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_3, peer_run=simulate_job]: got result from client site_3 for task: name=train, id=94730f40-ddc2-4a3b-8fbc-8e1b4954529c
# Epoch 8:  53%|█████▎    | 9/17 [00:00<00:00, 16.12it/s, v_num=0]2025-07-13 10:18:45,480 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_3, peer_run=simulate_job, peer_rc=OK, task_name=train, task_id=94730f40-ddc2-4a3b-8fbc-8e1b4954529c]: finished processing client result by controller
# 2025-07-13 10:18:45,481 - SubmitUpdateCommand - INFO - submit_update process. client_name:site_3   task_id:94730f40-ddc2-4a3b-8fbc-8e1b4954529c
# Epoch 7:  76%|███████▋  | 13/17 [00:00<00:00, 17.33it/s, v_num=0]2025-07-13 10:18:45,489 - Communicator - INFO -  SubmitUpdate size: 36.2KB (36191 Bytes). time: 0.538692 seconds
# 2025-07-13 10:18:45,490 - ClientRunner - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=94730f40-ddc2-4a3b-8fbc-8e1b4954529c]: task result sent to server
# 2025-07-13 10:18:45,491 - ClientTaskWorker - INFO - Finished one task run for client: site_3 interval: 2 task_processed: True
# Epoch 7: 100%|██████████| 17/17 [00:00<00:00, 17.64it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 8:  82%|████████▏ | 14/17 [00:00<00:00, 16.70it/s, v_num=0]
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 101.55it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 36.24it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 46.58it/s]
# Epoch 8: 100%|██████████| 17/17 [00:00<00:00, 17.12it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 8:  12%|█▏        | 2/17 [00:00<00:01, 14.96it/s, v_num=0]8it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 39.40it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 51.60it/s]
# Epoch 8: 100%|██████████| 17/17 [00:01<00:00, 16.27it/s, v_num=0]
# Epoch 9:  82%|████████▏ | 14/17 [00:00<00:00, 16.20it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 9:  88%|████████▊ | 15/17 [00:00<00:00, 16.34it/s, v_num=0]it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 37.80it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 50.09it/s]
# Epoch 9: 100%|██████████| 17/17 [00:01<00:00, 16.89it/s, v_num=0]
# Epoch 9:   6%|▌         | 1/17 [00:00<00:00, 19.40it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 9:  12%|█▏        | 2/17 [00:00<00:00, 18.99it/s, v_num=0]8it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 41.07it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 52.40it/s]
# Epoch 9: 100%|██████████| 17/17 [00:00<00:00, 17.61it/s, v_num=0]]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 10:  82%|████████▏ | 14/17 [00:00<00:00, 16.40it/s, v_num=0]
# Epoch 10:  88%|████████▊ | 15/17 [00:00<00:00, 16.39it/s, v_num=0]t/s]
# Epoch 10:  88%|████████▊ | 15/17 [00:00<00:00, 16.38it/s, v_num=0]]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 41.98it/s]
# Epoch 10: 100%|██████████| 17/17 [00:01<00:00, 16.92it/s, v_num=0]
# Epoch 10:   6%|▌         | 1/17 [00:00<00:01, 15.97it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 10:  12%|█▏        | 2/17 [00:00<00:00, 17.88it/s, v_num=0]6it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 44.82it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 56.47it/s]
# Epoch 10: 100%|██████████| 17/17 [00:00<00:00, 17.56it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 11:  82%|████████▏ | 14/17 [00:00<00:00, 16.59it/s, v_num=0]
# Epoch 11:  88%|████████▊ | 15/17 [00:00<00:00, 16.72it/s, v_num=0]t/s]
# Epoch 11:  88%|████████▊ | 15/17 [00:00<00:00, 16.70it/s, v_num=0]t/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 44.79it/s]
# Epoch 11: 100%|██████████| 17/17 [00:00<00:00, 17.19it/s, v_num=0]
# Epoch 11:   6%|▌         | 1/17 [00:00<00:01, 14.60it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 11:  12%|█▏        | 2/17 [00:00<00:00, 16.44it/s, v_num=0]2it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 44.15it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 57.50it/s]
# Epoch 11: 100%|██████████| 17/17 [00:00<00:00, 17.43it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 12:  88%|████████▊ | 15/17 [00:00<00:00, 17.58it/s, v_num=0]
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 76.43it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 38.33it/s]
# Epoch 12:  94%|█████████▍| 16/17 [00:00<00:00, 17.63it/s, v_num=0]t/s]
# Epoch 12: 100%|██████████| 17/17 [00:00<00:00, 18.08it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 12:   6%|▌         | 1/17 [00:00<00:00, 16.20it/s, v_num=0]
# Epoch 12:   6%|▌         | 1/17 [00:00<00:01, 15.97it/s, v_num=0]it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 36.75it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 46.52it/s]
# Epoch 12: 100%|██████████| 17/17 [00:01<00:00, 16.03it/s, v_num=0]
# 2025-07-13 10:18:50,405 - InProcessClientAPI - INFO - Try to send local model back to peer
# Epoch 12:  35%|███▌      | 6/17 [00:00<00:00, 18.39it/s, v_num=0]2025-07-13 10:18:50,604 - ClientRunner - INFO - [identity=site_1, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=77f793fe-0a3e-4dbb-992a-9bf646500921]: finished processing task
# 2025-07-13 10:18:50,605 - ClientRunner - INFO - [identity=site_1, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=77f793fe-0a3e-4dbb-992a-9bf646500921]: try #1: sending task result to server
# 2025-07-13 10:18:50,605 - ClientRunner - INFO - [identity=site_1, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=77f793fe-0a3e-4dbb-992a-9bf646500921]: checking task ...
# 2025-07-13 10:18:50,607 - Cell - INFO - broadcast: channel='aux_communication', topic='__task_check__', targets=['server.simulate_job'], timeout=5.0
# 2025-07-13 10:18:50,620 - ClientRunner - INFO - [identity=site_1, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=77f793fe-0a3e-4dbb-992a-9bf646500921]: start to send task result to server
# 2025-07-13 10:18:50,621 - FederatedClient - INFO - Starting to push execute result.
# 2025-07-13 10:18:50,635 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_1, peer_run=simulate_job]: got result from client site_1 for task: name=train, id=77f793fe-0a3e-4dbb-992a-9bf646500921
# Epoch 12:  76%|███████▋  | 13/17 [00:00<00:00, 18.46it/s, v_num=0]2025-07-13 10:18:51,006 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_1, peer_run=simulate_job, peer_rc=OK, task_name=train, task_id=77f793fe-0a3e-4dbb-992a-9bf646500921]: finished processing client result by controller
# 2025-07-13 10:18:51,008 - SubmitUpdateCommand - INFO - submit_update process. client_name:site_1   task_id:77f793fe-0a3e-4dbb-992a-9bf646500921
# 2025-07-13 10:18:51,014 - Communicator - INFO -  SubmitUpdate size: 36.2KB (36191 Bytes). time: 0.393117 seconds
# 2025-07-13 10:18:51,015 - ClientRunner - INFO - [identity=site_1, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=77f793fe-0a3e-4dbb-992a-9bf646500921]: task result sent to server
# 2025-07-13 10:18:51,016 - ClientTaskWorker - INFO - Finished one task run for client: site_1 interval: 2 task_processed: True
# Epoch 12: 100%|██████████| 17/17 [00:00<00:00, 19.10it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 83.42it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 43.94it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 55.64it/s]
# Epoch 13: 100%|██████████| 17/17 [00:00<00:00, 20.13it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 102.23it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 45.43it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 57.19it/s]
# ...
# 2025-07-13 10:19:22,295 - ClientRunner - INFO - [identity=site_1, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=1b97bf9f-b77d-404e-a960-44971c308a6b]: start to send task result to server
# 2025-07-13 10:19:22,296 - FederatedClient - INFO - Starting to push execute result.
# Epoch 22:  82%|████████▏ | 14/17 [00:00<00:00, 15.11it/s, v_num=0]2025-07-13 10:19:22,307 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_1, peer_run=simulate_job]: got result from client site_1 for task: name=train, id=1b97bf9f-b77d-404e-a960-44971c308a6b
# 2025-07-13 10:19:22,309 - IntimeModelSelector - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_1, peer_run=simulate_job, peer_rc=OK, task_name=train, task_id=1b97bf9f-b77d-404e-a960-44971c308a6b]: validation metric 0.787268340587616 from client site_1
# Epoch 22: 100%|██████████| 17/17 [00:01<00:00, 16.05it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 87.15it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 44.77it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 57.21it/s]
# Epoch 22: 100%|██████████| 17/17 [00:01<00:00, 14.60it/s, v_num=0]
# 2025-07-13 10:19:22,540 - InProcessClientAPI - INFO - Try to send local model back to peer
# 2025-07-13 10:19:22,594 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_1, peer_run=simulate_job, peer_rc=OK, task_name=train, task_id=1b97bf9f-b77d-404e-a960-44971c308a6b]: finished processing client result by controller
# 2025-07-13 10:19:22,595 - SubmitUpdateCommand - INFO - submit_update process. client_name:site_1   task_id:1b97bf9f-b77d-404e-a960-44971c308a6b
# 2025-07-13 10:19:22,599 - Communicator - INFO -  SubmitUpdate size: 36.2KB (36191 Bytes). time: 0.303269 seconds
# 2025-07-13 10:19:22,600 - ClientRunner - INFO - [identity=site_1, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=1b97bf9f-b77d-404e-a960-44971c308a6b]: task result sent to server
# 2025-07-13 10:19:22,601 - ClientTaskWorker - INFO - Finished one task run for client: site_1 interval: 2 task_processed: True
# 2025-07-13 10:19:22,670 - ClientRunner - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=9de34c3a-141a-4cf3-9046-2674b5298b58]: finished processing task
# 2025-07-13 10:19:22,671 - ClientRunner - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=9de34c3a-141a-4cf3-9046-2674b5298b58]: try #1: sending task result to server
# 2025-07-13 10:19:22,671 - ClientRunner - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=9de34c3a-141a-4cf3-9046-2674b5298b58]: checking task ...
# 2025-07-13 10:19:22,672 - Cell - INFO - broadcast: channel='aux_communication', topic='__task_check__', targets=['server.simulate_job'], timeout=5.0
# 2025-07-13 10:19:22,684 - ClientRunner - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=9de34c3a-141a-4cf3-9046-2674b5298b58]: start to send task result to server
# 2025-07-13 10:19:22,685 - FederatedClient - INFO - Starting to push execute result.
# 2025-07-13 10:19:22,697 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_3, peer_run=simulate_job]: got result from client site_3 for task: name=train, id=9de34c3a-141a-4cf3-9046-2674b5298b58
# 2025-07-13 10:19:22,699 - IntimeModelSelector - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_3, peer_run=simulate_job, peer_rc=OK, task_name=train, task_id=9de34c3a-141a-4cf3-9046-2674b5298b58]: validation metric 0.8241653442382812 from client site_3
# 2025-07-13 10:19:22,955 - ClientRunner - INFO - [identity=site_2, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=a79c480e-861c-4089-b2f2-491c7806a172]: finished processing task
# 2025-07-13 10:19:22,956 - ClientRunner - INFO - [identity=site_2, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=a79c480e-861c-4089-b2f2-491c7806a172]: try #1: sending task result to server
# 2025-07-13 10:19:22,957 - ClientRunner - INFO - [identity=site_2, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=a79c480e-861c-4089-b2f2-491c7806a172]: checking task ...
# 2025-07-13 10:19:22,958 - Cell - INFO - broadcast: channel='aux_communication', topic='__task_check__', targets=['server.simulate_job'], timeout=5.0
# 2025-07-13 10:19:22,981 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_3, peer_run=simulate_job, peer_rc=OK, task_name=train, task_id=9de34c3a-141a-4cf3-9046-2674b5298b58]: finished processing client result by controller
# 2025-07-13 10:19:22,983 - SubmitUpdateCommand - INFO - submit_update process. client_name:site_3   task_id:9de34c3a-141a-4cf3-9046-2674b5298b58
# 2025-07-13 10:19:22,989 - ClientRunner - INFO - [identity=site_2, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=a79c480e-861c-4089-b2f2-491c7806a172]: start to send task result to server
# 2025-07-13 10:19:22,989 - FederatedClient - INFO - Starting to push execute result.
# 2025-07-13 10:19:22,990 - Communicator - INFO -  SubmitUpdate size: 36.2KB (36191 Bytes). time: 0.304964 seconds
# 2025-07-13 10:19:22,991 - ClientRunner - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=9de34c3a-141a-4cf3-9046-2674b5298b58]: task result sent to server
# 2025-07-13 10:19:22,991 - ClientTaskWorker - INFO - Finished one task run for client: site_3 interval: 2 task_processed: True
# 2025-07-13 10:19:23,000 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_2, peer_run=simulate_job]: got result from client site_2 for task: name=train, id=a79c480e-861c-4089-b2f2-491c7806a172
# 2025-07-13 10:19:23,002 - IntimeModelSelector - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_2, peer_run=simulate_job, peer_rc=OK, task_name=train, task_id=a79c480e-861c-4089-b2f2-491c7806a172]: validation metric 0.7982437014579773 from client site_2
# 2025-07-13 10:19:23,267 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_2, peer_run=simulate_job, peer_rc=OK, task_name=train, task_id=a79c480e-861c-4089-b2f2-491c7806a172]: finished processing client result by controller
# 2025-07-13 10:19:23,267 - WFCommServer - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: task train exit with status TaskCompletionStatus.OK
# 2025-07-13 10:19:23,268 - SubmitUpdateCommand - INFO - submit_update process. client_name:site_2   task_id:a79c480e-861c-4089-b2f2-491c7806a172
# 2025-07-13 10:19:23,272 - Communicator - INFO -  SubmitUpdate size: 36.2KB (36191 Bytes). time: 0.282854 seconds
# 2025-07-13 10:19:23,273 - ClientRunner - INFO - [identity=site_2, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=a79c480e-861c-4089-b2f2-491c7806a172]: task result sent to server
# 2025-07-13 10:19:23,274 - ClientTaskWorker - INFO - Finished one task run for client: site_2 interval: 2 task_processed: True
# 2025-07-13 10:19:23,467 - FedAvg - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_2, peer_run=simulate_job, peer_rc=OK, task_name=train, task_id=a79c480e-861c-4089-b2f2-491c7806a172]: aggregating 3 update(s) at round 4
# 2025-07-13 10:19:23,470 - FedAvg - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_2, peer_run=simulate_job, peer_rc=OK, task_name=train, task_id=a79c480e-861c-4089-b2f2-491c7806a172]: Start persist model on server.
# 2025-07-13 10:19:23,477 - FedAvg - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_2, peer_run=simulate_job, peer_rc=OK, task_name=train, task_id=a79c480e-861c-4089-b2f2-491c7806a172]: End persist model on server.
# 2025-07-13 10:19:23,477 - FedAvg - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_2, peer_run=simulate_job, peer_rc=OK, task_name=train, task_id=a79c480e-861c-4089-b2f2-491c7806a172]: Finished FedAvg.
# 2025-07-13 10:19:23,478 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: Workflow: controller finalizing ...
# 2025-07-13 10:19:23,479 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: ABOUT_TO_END_RUN fired
# 2025-07-13 10:19:23,485 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: Firing CHECK_END_RUN_READINESS ...
# 2025-07-13 10:19:23,488 - ClientRunner - INFO - [identity=site_2, run=simulate_job, peer=simulator_server, peer_run=simulate_job]: received request from Server to end current RUN
# 2025-07-13 10:19:23,488 - ClientRunner - INFO - [identity=site_1, run=simulate_job, peer=simulator_server, peer_run=simulate_job]: received request from Server to end current RUN
# 2025-07-13 10:19:23,489 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: END_RUN fired
# 2025-07-13 10:19:23,489 - ReliableMessage - INFO - ReliableMessage is shutdown
# 2025-07-13 10:19:23,489 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: Server runner finished.
# 2025-07-13 10:19:23,490 - ClientRunner - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job]: received request from Server to end current RUN
# 2025-07-13 10:19:23,938 - ReliableMessage - INFO - shutdown reliable message monitor
# 2025-07-13 10:19:24,609 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_1, peer_run=simulate_job]: server runner is finalizing - asked client to end the run
# 2025-07-13 10:19:24,609 - GetTaskCommand - INFO - return task to client.  client_name: site_1  task_name: __end_run__   task_id:   sharable_header_task_id:
# 2025-07-13 10:19:24,613 - FederatedClient - INFO - pull_task completed. Task name:__end_run__ Status:True
# 2025-07-13 10:19:24,614 - ClientRunner - INFO - [identity=site_1, run=simulate_job, peer=simulator_server, peer_run=simulate_job]: server asked to end the run
# 2025-07-13 10:19:24,614 - ClientRunner - INFO - [identity=site_1, run=simulate_job]: started end-run events sequence
# 2025-07-13 10:19:24,615 - ClientRunner - INFO - [identity=site_1, run=simulate_job]: ABOUT_TO_END_RUN fired
# 2025-07-13 10:19:24,615 - ClientRunner - INFO - [identity=site_1, run=simulate_job]: Firing CHECK_END_RUN_READINESS ...
# 2025-07-13 10:19:24,617 - InProcessClientAPI - WARNING - ask to stop job: reason: END_RUN received
# 2025-07-13 10:19:24,917 - InProcessClientAPI - WARNING - request to stop the job for reason END_RUN received
# 2025-07-13 10:19:24,918 - ClientRunner - INFO - [identity=site_1, run=simulate_job]: END_RUN fired
# 2025-07-13 10:19:24,919 - ClientTaskWorker - INFO - End the Simulator run.
# 2025-07-13 10:19:24,961 - ClientTaskWorker - INFO - Clean up ClientRunner for : site_1
# 2025-07-13 10:19:24,965 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connection [CN00007 Not Connected] is closed PID: 594320
# 2025-07-13 10:19:24,965 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connection [CN00002 Not Connected] is closed PID: 594385
# 2025-07-13 10:19:24,999 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_3, peer_run=simulate_job]: server runner is finalizing - asked client to end the run
# 2025-07-13 10:19:25,000 - GetTaskCommand - INFO - return task to client.  client_name: site_3  task_name: __end_run__   task_id:   sharable_header_task_id:
# 2025-07-13 10:19:25,004 - FederatedClient - INFO - pull_task completed. Task name:__end_run__ Status:True
# 2025-07-13 10:19:25,005 - ClientRunner - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job]: server asked to end the run
# 2025-07-13 10:19:25,005 - ClientRunner - INFO - [identity=site_3, run=simulate_job]: started end-run events sequence
# 2025-07-13 10:19:25,006 - ClientRunner - INFO - [identity=site_3, run=simulate_job]: ABOUT_TO_END_RUN fired
# 2025-07-13 10:19:25,006 - ClientRunner - INFO - [identity=site_3, run=simulate_job]: Firing CHECK_END_RUN_READINESS ...
# 2025-07-13 10:19:25,008 - InProcessClientAPI - WARNING - ask to stop job: reason: END_RUN received
# 2025-07-13 10:19:25,267 - InProcessClientAPI - WARNING - request to stop the job for reason END_RUN received
# 2025-07-13 10:19:25,268 - ClientRunner - INFO - [identity=site_3, run=simulate_job]: END_RUN fired
# 2025-07-13 10:19:25,269 - ClientTaskWorker - INFO - End the Simulator run.
# 2025-07-13 10:19:25,280 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_2, peer_run=simulate_job]: server runner is finalizing - asked client to end the run
# 2025-07-13 10:19:25,281 - GetTaskCommand - INFO - return task to client.  client_name: site_2  task_name: __end_run__   task_id:   sharable_header_task_id:
# 2025-07-13 10:19:25,284 - FederatedClient - INFO - pull_task completed. Task name:__end_run__ Status:True
# 2025-07-13 10:19:25,285 - ClientRunner - INFO - [identity=site_2, run=simulate_job, peer=simulator_server, peer_run=simulate_job]: server asked to end the run
# 2025-07-13 10:19:25,286 - ClientRunner - INFO - [identity=site_2, run=simulate_job]: started end-run events sequence
# 2025-07-13 10:19:25,286 - ClientRunner - INFO - [identity=site_2, run=simulate_job]: ABOUT_TO_END_RUN fired
# 2025-07-13 10:19:25,287 - ClientRunner - INFO - [identity=site_2, run=simulate_job]: Firing CHECK_END_RUN_READINESS ...
# 2025-07-13 10:19:25,288 - InProcessClientAPI - WARNING - ask to stop job: reason: END_RUN received
# 2025-07-13 10:19:25,311 - ClientTaskWorker - INFO - Clean up ClientRunner for : site_3
# 2025-07-13 10:19:25,314 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connection [CN00008 Not Connected] is closed PID: 594320
# 2025-07-13 10:19:25,315 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connection [CN00002 Not Connected] is closed PID: 594387
# 2025-07-13 10:19:25,558 - InProcessClientAPI - WARNING - request to stop the job for reason END_RUN received
# 2025-07-13 10:19:25,559 - ClientRunner - INFO - [identity=site_2, run=simulate_job]: END_RUN fired
# 2025-07-13 10:19:25,560 - ClientTaskWorker - INFO - End the Simulator run.
# 2025-07-13 10:19:25,594 - SimulatorServer - INFO - Server app stopped.
#
#
# 2025-07-13 10:19:25,605 - ClientTaskWorker - INFO - Clean up ClientRunner for : site_2
# 2025-07-13 10:19:25,606 - FederatedClient - INFO - Shutting down client run: site_1
# 2025-07-13 10:19:25,608 - FederatedClient - INFO - Shutting down client run: site_2
# 2025-07-13 10:19:25,608 - FederatedClient - INFO - Shutting down client run: site_3
# 2025-07-13 10:19:25,610 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: asked to abort - triggered abort_signal to stop the RUN
# 2025-07-13 10:19:25,611 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connection [CN00006 Not Connected] is closed PID: 594320
# 2025-07-13 10:19:25,611 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connection [CN00002 Not Connected] is closed PID: 594386
# 2025-07-13 10:19:25,769 - nvflare.fuel.hci.server.hci - INFO - Admin Server localhost on Port 51323 shutdown!
# 2025-07-13 10:19:25,769 - SimulatorServer - INFO - shutting down server
# 2025-07-13 10:19:25,770 - SimulatorServer - INFO - canceling sync locks
# 2025-07-13 10:19:25,770 - SimulatorServer - INFO - server off
# 2025-07-13 10:19:29,275 - MPM - INFO - MPM: Good Bye!
