# %%
from meps_model import UnWeightedLitDNN

from nvflare.app_common.workflows.fedavg import FedAvg
from nvflare.app_opt.pt.job_config.base_fed_job import BaseFedJob
from nvflare.job_config.script_runner import ScriptRunner

# %%
job = BaseFedJob(
    name="meps_lightning_fedavg",
    initial_model=UnWeightedLitDNN(),
    key_metric="val_loss"
)

# %%
n_clients = 3

controller = FedAvg(
    num_clients=n_clients,
    num_rounds=5,
)
job.to(controller, "server")

# %%
for i in range(n_clients):
    runner = ScriptRunner(
        script="meps_nvflare.py", script_args=f"--batch_size 256 --local_epochs 100 --no-weights --dataset_path /data/shared/analysis/bias_fairness/for_fl/site_{i+1}"
    )
    job.to(runner, f"site_{i+1}")

# %%
job.simulator_run("/data/shared/analysis/bias_fairness/nvflare_wkdir")
# Out:
# 2025-07-13 09:22:41,273 - SimulatorRunner - INFO - Create the Simulator Server.
# 2025-07-13 09:22:41,277 - CoreCell - INFO - server: creating listener on tcp://0:57403
# 2025-07-13 09:22:41,343 - CoreCell - INFO - server: created backbone external listener for tcp://0:57403
# 2025-07-13 09:22:41,344 - ConnectorManager - INFO - 545801: Try start_listener Listener resources: {'secure': False, 'host': 'localhost'}
# 2025-07-13 09:22:41,347 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connector [CH00002 PASSIVE tcp://0:17452] is starting
# 2025-07-13 09:22:41,849 - CoreCell - INFO - server: created backbone internal listener for tcp://localhost:17452
# 2025-07-13 09:22:41,850 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connector [CH00001 PASSIVE tcp://0:57403] is starting
# 2025-07-13 09:22:41,853 - SimulatorServer - INFO - max_reg_duration=60.0
# 2025-07-13 09:22:42,142 - nvflare.fuel.hci.server.hci - INFO - Starting Admin Server localhost on Port 33733
# 2025-07-13 09:22:42,143 - SimulatorRunner - INFO - Deploy the Apps.
# 2025-07-13 09:22:42,171 - SimulatorRunner - INFO - Create the simulate clients.
# 2025-07-13 09:22:42,181 - Communicator - INFO - Trying to register with server ...
# 2025-07-13 09:22:42,182 - ClientManager - INFO - authenticated client site_1
# 2025-07-13 09:22:42,183 - ClientManager - INFO - Client: New client site_1@137.53.221.88 joined. Sent token: 04f187d9-6cf9-42a6-9f32-f8e5c67702ce.  Total clients: 1
# 2025-07-13 09:22:42,184 - Communicator - INFO - register RC: ok
# 2025-07-13 09:22:42,184 - FederatedClient - INFO - Successfully registered client:site_1 for project simulator_server. Token:04f187d9-6cf9-42a6-9f32-f8e5c67702ce SSID:
# 2025-07-13 09:22:42,187 - Communicator - INFO - Trying to register with server ...
# 2025-07-13 09:22:42,188 - ClientManager - INFO - authenticated client site_2
# 2025-07-13 09:22:42,189 - ClientManager - INFO - Client: New client site_2@137.53.221.88 joined. Sent token: b76475b5-8707-49be-9e85-df6c8ba418ac.  Total clients: 2
# 2025-07-13 09:22:42,190 - Communicator - INFO - register RC: ok
# 2025-07-13 09:22:42,190 - FederatedClient - INFO - Successfully registered client:site_2 for project simulator_server. Token:b76475b5-8707-49be-9e85-df6c8ba418ac SSID:
# 2025-07-13 09:22:42,193 - Communicator - INFO - Trying to register with server ...
# 2025-07-13 09:22:42,195 - ClientManager - INFO - authenticated client site_3
# 2025-07-13 09:22:42,195 - ClientManager - INFO - Client: New client site_3@137.53.221.88 joined. Sent token: a9a1a19a-c9fb-4581-a48c-6364e0458d63.  Total clients: 3
# 2025-07-13 09:22:42,196 - Communicator - INFO - register RC: ok
# 2025-07-13 09:22:42,196 - FederatedClient - INFO - Successfully registered client:site_3 for project simulator_server. Token:a9a1a19a-c9fb-4581-a48c-6364e0458d63 SSID:
# 2025-07-13 09:22:42,197 - SimulatorRunner - INFO - Set the client status ready.
# 2025-07-13 09:22:42,197 - SimulatorRunner - INFO - Deploy and start the Server App.
# 2025-07-13 09:22:42,200 - Cell - INFO - Register blob CB for channel='server_command', topic='*'
# 2025-07-13 09:22:42,201 - Cell - INFO - Register blob CB for channel='aux_communication', topic='*'
# 2025-07-13 09:22:42,201 - ServerCommandAgent - INFO - ServerCommandAgent cell register_request_cb: server.simulate_job
# 2025-07-13 09:22:42,224 - IntimeModelSelector - INFO - model selection weights control: {}
# 2025-07-13 09:22:46,973 - AuxRunner - INFO - registered aux handler for topic __sync_runner__
# 2025-07-13 09:22:46,973 - AuxRunner - INFO - registered aux handler for topic __job_heartbeat__
# 2025-07-13 09:22:46,974 - AuxRunner - INFO - registered aux handler for topic __task_check__
# 2025-07-13 09:22:46,975 - AuxRunner - INFO - registered aux handler for topic RM.RELIABLE_REQUEST
# 2025-07-13 09:22:46,975 - AuxRunner - INFO - registered aux handler for topic RM.RELIABLE_REPLY
# 2025-07-13 09:22:46,976 - ReliableMessage - INFO - enabled reliable message: max_request_workers=20 query_interval=2.0
# 2025-07-13 09:22:46,976 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job]: Server runner starting ...
# 2025-07-13 09:22:46,976 - TBAnalyticsReceiver - INFO - [identity=simulator_server, run=simulate_job]: Tensorboard records can be found in /data/shared/analysis/bias_fairness/nvflare_wkdir/server/simulate_job/tb_events you can view it using `tensorboard --logdir=/data/shared/analysis/bias_fairness/nvflare_wkdir/server/simulate_job/tb_events`
# 2025-07-13 09:22:46,977 - AuxRunner - INFO - registered aux handler for topic fed.event
# 2025-07-13 09:22:46,977 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job]: starting workflow controller (<class 'nvflare.app_common.workflows.fedavg.FedAvg'>) ...
# 2025-07-13 09:22:46,977 - FedAvg - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: Initializing BaseModelController workflow.
# 2025-07-13 09:22:46,977 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: Workflow controller (<class 'nvflare.app_common.workflows.fedavg.FedAvg'>) started
# 2025-07-13 09:22:46,978 - FedAvg - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: Beginning model controller run.
# 2025-07-13 09:22:46,978 - FedAvg - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: Start FedAvg.
# 2025-07-13 09:22:46,978 - FedAvg - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: loading initial model from persistor
# 2025-07-13 09:22:46,978 - PTFileModelPersistor - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: Both source_ckpt_file_full_name and ckpt_preload_path are not provided. Using the default model weights initialized on the persistor side.
# 2025-07-13 09:22:46,979 - FedAvg - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: Round 0 started.
# 2025-07-13 09:22:46,979 - FedAvg - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: Sampled clients: ['site_1', 'site_2', 'site_3']
# 2025-07-13 09:22:46,979 - FedAvg - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: Sending task train to ['site_1', 'site_2', 'site_3']
# 2025-07-13 09:22:46,979 - WFCommServer - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: scheduled task train
# 2025-07-13 09:22:47,343 - SimulatorClientRunner - INFO - Start the clients run simulation.
# 2025-07-13 09:22:48,345 - SimulatorClientRunner - INFO - Simulate Run client: site_1 on GPU group: None
# 2025-07-13 09:22:48,346 - SimulatorClientRunner - INFO - Simulate Run client: site_2 on GPU group: None
# 2025-07-13 09:22:48,366 - SimulatorClientRunner - INFO - Simulate Run client: site_3 on GPU group: None
# 2025-07-13 09:22:49,406 - ClientTaskWorker - INFO - ClientTaskWorker started to run
# 2025-07-13 09:22:49,407 - ClientTaskWorker - INFO - ClientTaskWorker started to run
# 2025-07-13 09:22:49,424 - ClientTaskWorker - INFO - ClientTaskWorker started to run
# 2025-07-13 09:22:49,473 - CoreCell - INFO - site_2.simulate_job: created backbone external connector to tcp://localhost:57403
# 2025-07-13 09:22:49,473 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connector [CH00001 ACTIVE tcp://localhost:57403] is starting
# 2025-07-13 09:22:49,473 - CoreCell - INFO - site_1.simulate_job: created backbone external connector to tcp://localhost:57403
# 2025-07-13 09:22:49,473 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connector [CH00001 ACTIVE tcp://localhost:57403] is starting
# 2025-07-13 09:22:49,474 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connection [CN00002 127.0.0.1:41414 => 127.0.0.1:57403] is created: PID: 545871
# 2025-07-13 09:22:49,475 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connection [CN00002 127.0.0.1:41428 => 127.0.0.1:57403] is created: PID: 545870
# 2025-07-13 09:22:49,475 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connection [CN00006 127.0.0.1:57403 <= 127.0.0.1:41414] is created: PID: 545801
# 2025-07-13 09:22:49,476 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connection [CN00007 127.0.0.1:57403 <= 127.0.0.1:41428] is created: PID: 545801
# 2025-07-13 09:22:49,493 - CoreCell - INFO - site_3.simulate_job: created backbone external connector to tcp://localhost:57403
# 2025-07-13 09:22:49,493 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connector [CH00001 ACTIVE tcp://localhost:57403] is starting
# 2025-07-13 09:22:49,494 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connection [CN00002 127.0.0.1:41442 => 127.0.0.1:57403] is created: PID: 545872
# 2025-07-13 09:22:49,495 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connection [CN00008 127.0.0.1:57403 <= 127.0.0.1:41442] is created: PID: 545801
# 2025-07-13 09:22:52,010 - AuxRunner - INFO - registered aux handler for topic __end_run__
# 2025-07-13 09:22:52,010 - AuxRunner - INFO - registered aux handler for topic __do_task__
# 2025-07-13 09:22:52,011 - Cell - INFO - Register blob CB for channel='aux_communication', topic='*'
# 2025-07-13 09:22:52,015 - AuxRunner - INFO - registered aux handler for topic __end_run__
# 2025-07-13 09:22:52,016 - AuxRunner - INFO - registered aux handler for topic __do_task__
# 2025-07-13 09:22:52,016 - Cell - INFO - Register blob CB for channel='aux_communication', topic='*'
# 2025-07-13 09:22:52,282 - AuxRunner - INFO - registered aux handler for topic __end_run__
# 2025-07-13 09:22:52,282 - AuxRunner - INFO - registered aux handler for topic __do_task__
# 2025-07-13 09:22:52,283 - Cell - INFO - Register blob CB for channel='aux_communication', topic='*'
# 2025-07-13 09:22:52,516 - Cell - INFO - broadcast: channel='aux_communication', topic='__sync_runner__', targets=['server.simulate_job'], timeout=2.0
# 2025-07-13 09:22:52,522 - Cell - INFO - broadcast: channel='aux_communication', topic='__sync_runner__', targets=['server.simulate_job'], timeout=2.0
# 2025-07-13 09:22:52,531 - ClientRunner - INFO - [identity=site_1, run=simulate_job]: synced to Server Runner in 0.5151398181915283 seconds
# 2025-07-13 09:22:52,531 - AuxRunner - INFO - registered aux handler for topic RM.RELIABLE_REQUEST
# 2025-07-13 09:22:52,532 - AuxRunner - INFO - registered aux handler for topic RM.RELIABLE_REPLY
# 2025-07-13 09:22:52,532 - ReliableMessage - INFO - enabled reliable message: max_request_workers=20 query_interval=2.0
# 2025-07-13 09:22:52,534 - TaskScriptRunner - INFO - start task run() with full path: /data/shared/analysis/bias_fairness/nvflare_wkdir/site_1/simulate_job/app_site_1/custom/meps_nvflare.py
# 2025-07-13 09:22:52,534 - AuxRunner - INFO - registered aux handler for topic fed.event
# 2025-07-13 09:22:52,535 - ClientRunner - INFO - [identity=site_1, run=simulate_job]: client runner started
# 2025-07-13 09:22:52,535 - ClientTaskWorker - INFO - Initialize ClientRunner for client: site_1
# 2025-07-13 09:22:52,536 - ClientRunner - INFO - [identity=site_3, run=simulate_job]: synced to Server Runner in 0.5149385929107666 seconds
# 2025-07-13 09:22:52,537 - AuxRunner - INFO - registered aux handler for topic RM.RELIABLE_REQUEST
# 2025-07-13 09:22:52,537 - AuxRunner - INFO - registered aux handler for topic RM.RELIABLE_REPLY
# 2025-07-13 09:22:52,538 - ReliableMessage - INFO - enabled reliable message: max_request_workers=20 query_interval=2.0
# 2025-07-13 09:22:52,540 - TaskScriptRunner - INFO - start task run() with full path: /data/shared/analysis/bias_fairness/nvflare_wkdir/site_3/simulate_job/app_site_3/custom/meps_nvflare.py
# 2025-07-13 09:22:52,540 - AuxRunner - INFO - registered aux handler for topic fed.event
# 2025-07-13 09:22:52,541 - ClientRunner - INFO - [identity=site_3, run=simulate_job]: client runner started
# 2025-07-13 09:22:52,542 - ClientTaskWorker - INFO - Initialize ClientRunner for client: site_3
# 2025-07-13 09:22:52,544 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_1, peer_run=simulate_job, task_name=train, task_id=07c5fce9-b289-4893-b51c-dbef7daffaf0]: assigned task to client site_1: name=train, id=07c5fce9-b289-4893-b51c-dbef7daffaf0
# 2025-07-13 09:22:52,545 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_1, peer_run=simulate_job, task_name=train, task_id=07c5fce9-b289-4893-b51c-dbef7daffaf0]: sent task assignment to client. client_name:site_1 task_id:07c5fce9-b289-4893-b51c-dbef7daffaf0
# 2025-07-13 09:22:52,545 - GetTaskCommand - INFO - return task to client.  client_name: site_1  task_name: train   task_id: 07c5fce9-b289-4893-b51c-dbef7daffaf0  sharable_header_task_id: 07c5fce9-b289-4893-b51c-dbef7daffaf0
# 2025-07-13 09:22:52,553 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_3, peer_run=simulate_job, task_name=train, task_id=4c1d65fd-75f6-4fcd-9201-229811deb787]: assigned task to client site_3: name=train, id=4c1d65fd-75f6-4fcd-9201-229811deb787
# 2025-07-13 09:22:52,554 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_3, peer_run=simulate_job, task_name=train, task_id=4c1d65fd-75f6-4fcd-9201-229811deb787]: sent task assignment to client. client_name:site_3 task_id:4c1d65fd-75f6-4fcd-9201-229811deb787
# 2025-07-13 09:22:52,555 - GetTaskCommand - INFO - return task to client.  client_name: site_3  task_name: train   task_id: 4c1d65fd-75f6-4fcd-9201-229811deb787  sharable_header_task_id: 4c1d65fd-75f6-4fcd-9201-229811deb787
# 2025-07-13 09:22:52,557 - Communicator - INFO - Received from simulator_server server. getTask: train size: 36.2KB (36205 Bytes) time: 0.020468 seconds
# 2025-07-13 09:22:52,558 - FederatedClient - INFO - pull_task completed. Task name:train Status:True
# 2025-07-13 09:22:52,559 - ClientRunner - INFO - [identity=site_1, run=simulate_job, peer=simulator_server, peer_run=simulate_job]: got task assignment: name=train, id=07c5fce9-b289-4893-b51c-dbef7daffaf0
# 2025-07-13 09:22:52,561 - ClientRunner - INFO - [identity=site_1, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=07c5fce9-b289-4893-b51c-dbef7daffaf0]: invoking task executor PTInProcessClientAPIExecutor
# 2025-07-13 09:22:52,561 - PTInProcessClientAPIExecutor - INFO - [identity=site_1, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=07c5fce9-b289-4893-b51c-dbef7daffaf0]: execute for task (train)
# 2025-07-13 09:22:52,563 - PTInProcessClientAPIExecutor - INFO - [identity=site_1, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=07c5fce9-b289-4893-b51c-dbef7daffaf0]: send data to peer
# 2025-07-13 09:22:52,564 - PTInProcessClientAPIExecutor - INFO - [identity=site_1, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=07c5fce9-b289-4893-b51c-dbef7daffaf0]: sending payload to peer
# 2025-07-13 09:22:52,566 - Communicator - INFO - Received from simulator_server server. getTask: train size: 36.2KB (36205 Bytes) time: 0.020974 seconds
# 2025-07-13 09:22:52,567 - PTInProcessClientAPIExecutor - INFO - [identity=site_1, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=07c5fce9-b289-4893-b51c-dbef7daffaf0]: Waiting for result from peer
# 2025-07-13 09:22:52,567 - FederatedClient - INFO - pull_task completed. Task name:train Status:True
# 2025-07-13 09:22:52,569 - ClientRunner - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job]: got task assignment: name=train, id=4c1d65fd-75f6-4fcd-9201-229811deb787
# 2025-07-13 09:22:52,571 - ClientRunner - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=4c1d65fd-75f6-4fcd-9201-229811deb787]: invoking task executor PTInProcessClientAPIExecutor
# 2025-07-13 09:22:52,572 - PTInProcessClientAPIExecutor - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=4c1d65fd-75f6-4fcd-9201-229811deb787]: execute for task (train)
# 2025-07-13 09:22:52,574 - PTInProcessClientAPIExecutor - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=4c1d65fd-75f6-4fcd-9201-229811deb787]: send data to peer
# 2025-07-13 09:22:52,574 - PTInProcessClientAPIExecutor - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=4c1d65fd-75f6-4fcd-9201-229811deb787]: sending payload to peer
# 2025-07-13 09:22:52,578 - PTInProcessClientAPIExecutor - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=4c1d65fd-75f6-4fcd-9201-229811deb787]: Waiting for result from peer
# 2025-07-13 09:22:52,789 - Cell - INFO - broadcast: channel='aux_communication', topic='__sync_runner__', targets=['server.simulate_job'], timeout=2.0
# 2025-07-13 09:22:52,801 - ClientRunner - INFO - [identity=site_2, run=simulate_job]: synced to Server Runner in 0.5128624439239502 seconds
# 2025-07-13 09:22:52,802 - AuxRunner - INFO - registered aux handler for topic RM.RELIABLE_REQUEST
# 2025-07-13 09:22:52,802 - AuxRunner - INFO - registered aux handler for topic RM.RELIABLE_REPLY
# 2025-07-13 09:22:52,803 - ReliableMessage - INFO - enabled reliable message: max_request_workers=20 query_interval=2.0
# 2025-07-13 09:22:52,805 - TaskScriptRunner - INFO - start task run() with full path: /data/shared/analysis/bias_fairness/nvflare_wkdir/site_2/simulate_job/app_site_2/custom/meps_nvflare.py
# 2025-07-13 09:22:52,806 - AuxRunner - INFO - registered aux handler for topic fed.event
# 2025-07-13 09:22:52,807 - ClientRunner - INFO - [identity=site_2, run=simulate_job]: client runner started
# 2025-07-13 09:22:52,808 - ClientTaskWorker - INFO - Initialize ClientRunner for client: site_2
# 2025-07-13 09:22:52,819 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_2, peer_run=simulate_job, task_name=train, task_id=bde3581f-ba38-4a14-9314-5b8656075a12]: assigned task to client site_2: name=train, id=bde3581f-ba38-4a14-9314-5b8656075a12
# 2025-07-13 09:22:52,820 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_2, peer_run=simulate_job, task_name=train, task_id=bde3581f-ba38-4a14-9314-5b8656075a12]: sent task assignment to client. client_name:site_2 task_id:bde3581f-ba38-4a14-9314-5b8656075a12
# 2025-07-13 09:22:52,820 - GetTaskCommand - INFO - return task to client.  client_name: site_2  task_name: train   task_id: bde3581f-ba38-4a14-9314-5b8656075a12  sharable_header_task_id: bde3581f-ba38-4a14-9314-5b8656075a12
# 2025-07-13 09:22:52,831 - Communicator - INFO - Received from simulator_server server. getTask: train size: 36.2KB (36205 Bytes) time: 0.022315 seconds
# 2025-07-13 09:22:52,833 - FederatedClient - INFO - pull_task completed. Task name:train Status:True
# 2025-07-13 09:22:52,834 - ClientRunner - INFO - [identity=site_2, run=simulate_job, peer=simulator_server, peer_run=simulate_job]: got task assignment: name=train, id=bde3581f-ba38-4a14-9314-5b8656075a12
# 2025-07-13 09:22:52,837 - ClientRunner - INFO - [identity=site_2, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=bde3581f-ba38-4a14-9314-5b8656075a12]: invoking task executor PTInProcessClientAPIExecutor
# 2025-07-13 09:22:52,838 - PTInProcessClientAPIExecutor - INFO - [identity=site_2, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=bde3581f-ba38-4a14-9314-5b8656075a12]: execute for task (train)
# 2025-07-13 09:22:52,841 - PTInProcessClientAPIExecutor - INFO - [identity=site_2, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=bde3581f-ba38-4a14-9314-5b8656075a12]: send data to peer
# 2025-07-13 09:22:52,842 - PTInProcessClientAPIExecutor - INFO - [identity=site_2, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=bde3581f-ba38-4a14-9314-5b8656075a12]: sending payload to peer
# 2025-07-13 09:22:52,844 - PTInProcessClientAPIExecutor - INFO - [identity=site_2, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=bde3581f-ba38-4a14-9314-5b8656075a12]: Waiting for result from peer
# 2025-07-13 09:22:55,298 - pytorch_lightning.utilities.rank_zero - INFO - You are using the plain ModelCheckpoint callback. Consider using LitModelCheckpoint which with seamless uploading to Model registry.
# 2025-07-13 09:22:55,311 - pytorch_lightning.utilities.rank_zero - INFO - GPU available: False, used: False
# 2025-07-13 09:22:55,312 - pytorch_lightning.utilities.rank_zero - INFO - TPU available: False, using: 0 TPU cores
# 2025-07-13 09:22:55,312 - pytorch_lightning.utilities.rank_zero - INFO - HPU available: False, using: 0 HPUs
# 2025-07-13 09:22:55,313 - nvflare.app_common.executors.task_script_runner - INFO -
# [Current Round=0, Site = site_1]
#
# 2025-07-13 09:22:55,313 - nvflare.app_common.executors.task_script_runner - INFO - --- validate global model ---
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 91.47it/s]
# 2025-07-13 09:22:55,412 - nvflare.app_common.executors.task_script_runner - INFO - ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#      Validate metric           DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         val_loss            1.1747156381607056
# ──────────────────────────────────���─────────────────────────────────────────────────────────────────────────────────────
# 2025-07-13 09:22:55,413 - nvflare.app_common.executors.task_script_runner - INFO - --- train new model ---
# 2025-07-13 09:22:55,451 - lightning.pytorch.callbacks.model_summary - INFO -
#   | Name  | Type   | Params | Mode
# -----------------------------------------
# 0 | model | DeepNN | 7.6 K  | train
# -----------------------------------------
# 7.6 K     Trainable params
# 0         Non-trainable params
# 7.6 K     Total params
# 0.030     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# Epoch 0:   0%|          | 0/17 [00:00<?, ?it/s]
# INFO:
#   | Name  | Type   | Params | Mode
# -----------------------------------------
# 0 | model | DeepNN | 7.6 K  | train
# -----------------------------------------
# 7.6 K     Trainable params
# 0         Non-trainable params
# 7.6 K     Total params
# 0.030     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# Epoch 0:   6%|▌         | 1/17 [00:00<00:00, 47.00it/s, v_num=0]2025-07-13 09:22:55,515 - pytorch_lightning.utilities.rank_zero - INFO - You are using the plain ModelCheckpoint callback. Consider using LitModelCheckpoint which with seamless uploading to Model registry.
# Epoch 0:  12%|█▏        | 2/17 [00:00<00:00, 48.84it/s, v_num=0]2025-07-13 09:22:55,530 - pytorch_lightning.utilities.rank_zero - INFO - GPU available: False, used: False
# 2025-07-13 09:22:55,531 - pytorch_lightning.utilities.rank_zero - INFO - TPU available: False, using: 0 TPU cores
# 2025-07-13 09:22:55,531 - pytorch_lightning.utilities.rank_zero - INFO - HPU available: False, using: 0 HPUs
# 2025-07-13 09:22:55,532 - nvflare.app_common.executors.task_script_runner - INFO -
# [Current Round=0, Site = site_3]
#
# 2025-07-13 09:22:55,532 - nvflare.app_common.executors.task_script_runner - INFO - --- validate global model ---
# Epoch 0:  24%|██▎       | 4/17 [00:00<00:00, 50.37it/s, v_num=0]2025-07-13 09:22:55,564 - pytorch_lightning.utilities.rank_zero - INFO - You are using the plain ModelCheckpoint callback. Consider using LitModelCheckpoint which with seamless uploading to Model registry.
# 2025-07-13 09:22:55,578 - pytorch_lightning.utilities.rank_zero - INFO - GPU available: False, used: False
# 2025-07-13 09:22:55,578 - pytorch_lightning.utilities.rank_zero - INFO - TPU available: False, using: 0 TPU cores
# 2025-07-13 09:22:55,578 - pytorch_lightning.utilities.rank_zero - INFO - HPU available: False, using: 0 HPUs
# 2025-07-13 09:22:55,580 - nvflare.app_common.executors.task_script_runner - INFO -
# [Current Round=0, Site = site_2]
#
# 2025-07-13 09:22:55,580 - nvflare.app_common.executors.task_script_runner - INFO - --- validate global model ---
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 68.27it/s]
# 2025-07-13 09:22:55,661 - nvflare.app_common.executors.task_script_runner - INFO - ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#      Validate metric           DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         val_loss            1.1697794198989868
# ──────────────────────────────────���─────────────────────────────────────────────────────────────────────────────────────
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]2025-07-13 09:22:55,663 - nvflare.app_common.executors.task_script_runner - INFO - --- train new model ---
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 65.82it/s]2025-07-13 09:22:55,712 - lightning.pytorch.callbacks.model_summary - INFO -
#   | Name  | Type   | Params | Mode
# -----------------------------------------
# 0 | model | DeepNN | 7.6 K  | train
# -----------------------------------------
# 7.6 K     Trainable params
# 0         Non-trainable params
# 7.6 K     Total params
# 0.030     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 59.08it/s]
# 2025-07-13 09:22:55,713 - nvflare.app_common.executors.task_script_runner - INFO - ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#      Validate metric           DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         val_loss            1.1932116746902466
# ──────────────────────────────────���─────────────────────────────────────────────────────────────────────────────────────
# Epoch 0:  53%|█████▎    | 9/17 [00:00<00:00, 38.80it/s, v_num=0]2025-07-13 09:22:55,715 - nvflare.app_common.executors.task_script_runner - INFO - --- train new model ---
# Epoch 0:  65%|██████▍   | 11/17 [00:00<00:00, 40.24it/s, v_num=0]2025-07-13 09:22:55,765 - lightning.pytorch.callbacks.model_summary - INFO -
#   | Name  | Type   | Params | Mode
# -----------------------------------------
# 0 | model | DeepNN | 7.6 K  | train
# -----------------------------------------
# 7.6 K     Trainable params
# 0         Non-trainable params
# 7.6 K     Total params
# 0.030     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# Epoch 0:  12%|█▏        | 2/17 [00:00<00:00, 25.97it/s, v_num=0]]
# INFO:
#   | Name  | Type   | Params | Mode
# -----------------------------------------
# 0 | model | DeepNN | 7.6 K  | train
# -----------------------------------------
# 7.6 K     Trainable params
# 0         Non-trainable params
# 7.6 K     Total params
# 0.030     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# INFO:
#   | Name  | Type   | Params | Mode
# -----------------------------------------
# 0 | model | DeepNN | 7.6 K  | train
# -----------------------------------------
# 7.6 K     Trainable params
# 0         Non-trainable params
# 7.6 K     Total params
# 0.030     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# Epoch 0: 100%|██████████| 17/17 [00:00<00:00, 37.52it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 0:  24%|██▎       | 4/17 [00:00<00:00, 18.70it/s, v_num=0]1it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 43.16it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 57.54it/s]
# Epoch 0: 100%|██████████| 17/17 [00:00<00:00, 20.26it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 1:  76%|███████▋  | 13/17 [00:00<00:00, 20.73it/s, v_num=0]
# Epoch 0: 100%|██████████| 17/17 [00:00<00:00, 20.44it/s, v_num=0]2it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 60.61it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 79.54it/s]
# Epoch 1:  82%|████████▏ | 14/17 [00:00<00:00, 21.14it/s, v_num=0]
# Epoch 1:   0%|          | 0/17 [00:00<?, ?it/s, v_num=0]         0it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 69.06it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 85.77it/s]
# Epoch 1: 100%|██████████| 17/17 [00:00<00:00, 22.36it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 1:  12%|█▏        | 2/17 [00:00<00:00, 16.70it/s, v_num=0]A
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 55.05it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 49.29it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 46.40it/s]
# Epoch 1: 100%|██████████| 17/17 [00:00<00:00, 22.50it/s, v_num=0]
# Epoch 1: 100%|██████████| 17/17 [00:00<00:00, 23.24it/s, v_num=0]
# Epoch 2:  76%|███████▋  | 13/17 [00:00<00:00, 22.08it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 168.13it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 124.64it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 71.85it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 57.88it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 42.92it/s]
# Epoch 2:  82%|████████▏ | 14/17 [00:00<00:00, 21.63it/s, v_num=0]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 58.14it/s]
# Epoch 2: 100%|██████████| 17/17 [00:00<00:00, 22.97it/s, v_num=0]
# Epoch 2:  12%|█▏        | 2/17 [00:00<00:00, 22.73it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 2:  18%|█▊        | 3/17 [00:00<00:00, 23.47it/s, v_num=0]69it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 57.67it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 76.91it/s]
# Epoch 2: 100%|██████████| 17/17 [00:00<00:00, 26.15it/s, v_num=0]
# Epoch 2:  94%|█████████▍| 16/17 [00:00<00:00, 23.82it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 2: 100%|██████████| 17/17 [00:00<00:00, 24.44it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 51.14it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 3:  24%|██▎       | 4/17 [00:00<00:01,  7.14it/s, v_num=0]A
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 82.97it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 40.57it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 56.43it/s]
# Epoch 3:   0%|          | 0/17 [00:00<?, ?it/s, v_num=0]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 49.69it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 66.99it/s]
# Epoch 3: 100%|██████████| 17/17 [00:01<00:00, 12.13it/s, v_num=0]
# Epoch 3:  47%|████▋     | 8/17 [00:00<00:00,  9.92it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 3:  53%|█████▎    | 9/17 [00:00<00:00, 10.18it/s, v_num=0]7it/s]
# Epoch 3:  59%|█████▉    | 10/17 [00:00<00:00, 10.58it/s, v_num=0]it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 21.96it/s]
# Epoch 3: 100%|██████████| 17/17 [00:01<00:00, 11.29it/s, v_num=0]
# Epoch 3: 100%|██████████| 17/17 [00:01<00:00, 11.02it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]<?, ?it/s]
# Epoch 4:  24%|██▎       | 4/17 [00:00<00:01,  7.08it/s, v_num=0]
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 62.85it/s]
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 44.45it/s]
# Epoch 4:  29%|██▉       | 5/17 [00:00<00:01,  7.97it/s, v_num=0]6it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 23.70it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 33.30it/s]
# Epoch 3: 100%|██████████| 17/17 [00:01<00:00, 10.23it/s, v_num=0]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 31.38it/s]
# Epoch 4: 100%|██████████| 17/17 [00:01<00:00,  9.46it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 4:  76%|███████▋  | 13/17 [00:01<00:00, 11.14it/s, v_num=0]
# Epoch 4:  82%|████████▏ | 14/17 [00:01<00:00, 11.42it/s, v_num=0]it/s]
# Epoch 4:  82%|████████▏ | 14/17 [00:01<00:00, 11.41it/s, v_num=0]it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 32.41it/s]
# Epoch 4: 100%|██████████| 17/17 [00:01<00:00, 11.73it/s, v_num=0]
# Epoch 4: 100%|██████████| 17/17 [00:01<00:00, 11.57it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 83.24it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 5:  12%|█▏        | 2/17 [00:00<00:02,  7.41it/s, v_num=0]1it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 31.23it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 33.77it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 34.95it/s]
# Epoch 4: 100%|██████████| 17/17 [00:01<00:00, 10.81it/s, v_num=0]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 33.32it/s]
# Epoch 5: 100%|██████████| 17/17 [00:01<00:00, 11.96it/s, v_num=0]
# Epoch 5: 100%|██████████| 17/17 [00:01<00:00,  9.53it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 5:  94%|█████████▍| 16/17 [00:01<00:00, 10.84it/s, v_num=0]
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 89.11it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 5: 100%|██████████| 17/17 [00:01<00:00, 11.26it/s, v_num=0]6it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 37.05it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 48.98it/s]
# Epoch 5: 100%|██████████| 17/17 [00:01<00:00, 11.22it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]t/s, v_num=0]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 97.52it/s]
# Epoch 6:   0%|          | 0/17 [00:00<?, ?it/s, v_num=0]         it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 40.79it/s]
# Epoch 5: 100%|██████████| 17/17 [00:01<00:00,  8.99it/s, v_num=0]
# Epoch 6:   0%|          | 0/17 [00:00<?, ?it/s, v_num=0]         it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 62.10it/s]
# Epoch 6: 100%|██████████| 17/17 [00:01<00:00, 12.42it/s, v_num=0]
# Epoch 6:  82%|████████▏ | 14/17 [00:01<00:00, 10.29it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 59.39it/s]
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 38.03it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 24.55it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 20.72it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 24.14it/s]
# Epoch 6: 100%|██████████| 17/17 [00:01<00:00, 11.45it/s, v_num=0]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 21.76it/s]
# Epoch 6: 100%|██████████| 17/17 [00:01<00:00, 10.33it/s, v_num=0]
# Epoch 7:  12%|█▏        | 2/17 [00:00<00:01, 14.13it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 7:  12%|█▏        | 2/17 [00:00<00:01,  8.74it/s, v_num=0]6it/s]
# Epoch 7:  18%|█▊        | 3/17 [00:00<00:01, 11.81it/s, v_num=0]3it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 26.39it/s]
# Epoch 7: 100%|██████████| 17/17 [00:01<00:00, 10.63it/s, v_num=0]
# Epoch 7:  76%|███████▋  | 13/17 [00:01<00:00,  9.57it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 7: 100%|██████████| 17/17 [00:01<00:00, 10.01it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 12.36it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 7:  82%|████████▏ | 14/17 [00:01<00:00,  9.61it/s, v_num=0]
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 48.32it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 15.28it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 20.47it/s]
# Epoch 7: 100%|██████████| 17/17 [00:01<00:00,  9.50it/s, v_num=0]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 28.59it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 37.85it/s]
# Epoch 7: 100%|██████████| 17/17 [00:01<00:00,  9.89it/s, v_num=0]
# Epoch 8:   6%|▌         | 1/17 [00:00<00:03,  4.95it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 95.90it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 23.29it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 23.53it/s]
# Epoch 8: 100%|██████████| 17/17 [00:01<00:00, 10.18it/s, v_num=0]
# Epoch 8: 100%|██████████| 17/17 [00:01<00:00, 10.24it/s, v_num=0]
# Epoch 8:  82%|████████▏ | 14/17 [00:01<00:00, 10.60it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 118.13it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 120.84it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 45.83it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 51.42it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 38.06it/s]
# Epoch 8: 100%|██████████| 17/17 [00:01<00:00,  9.59it/s, v_num=0]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 42.36it/s]
# Epoch 8: 100%|██████████| 17/17 [00:01<00:00, 10.77it/s, v_num=0]
# Epoch 9:  18%|█▊        | 3/17 [00:00<00:00, 16.52it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 9:  24%|██▎       | 4/17 [00:00<00:00, 16.57it/s, v_num=0]0it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 25.62it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 30.53it/s]
# Epoch 9: 100%|██████████| 17/17 [00:01<00:00, 14.32it/s, v_num=0]
# Epoch 9:  82%|████████▏ | 14/17 [00:01<00:00, 11.60it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 98.97it/s]
# Epoch 9:  65%|██████▍   | 11/17 [00:00<00:00, 11.01it/s, v_num=0]it/s]
# Epoch 9:  88%|████████▊ | 15/17 [00:01<00:00, 11.42it/s, v_num=0]it/s]
# Epoch 9: 100%|██████████| 17/17 [00:01<00:00, 11.79it/s, v_num=0]
# Epoch 9:  76%|███████▋  | 13/17 [00:01<00:00, 11.35it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 10:  12%|█▏        | 2/17 [00:00<00:01, 13.04it/s, v_num=0]
# Epoch 9:  82%|████████▏ | 14/17 [00:01<00:00, 11.55it/s, v_num=0]it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 30.90it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 41.04it/s]
# Epoch 9: 100%|██████████| 17/17 [00:01<00:00, 12.10it/s, v_num=0]
# Epoch 10:  12%|█▏        | 2/17 [00:00<00:01, 12.90it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 10:  35%|███▌      | 6/17 [00:00<00:00, 14.41it/s, v_num=0]
# Epoch 10:  18%|█▊        | 3/17 [00:00<00:01, 11.14it/s, v_num=0]it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 16.42it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 22.27it/s]
# Epoch 10: 100%|██████████| 17/17 [00:01<00:00, 12.05it/s, v_num=0]
# Epoch 10:  53%|█████▎    | 9/17 [00:00<00:00, 10.26it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 10:  82%|████████▏ | 14/17 [00:01<00:00, 11.52it/s, v_num=0]it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 39.20it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 38.06it/s]
# Epoch 10: 100%|██████████| 17/17 [00:01<00:00, 11.83it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 11:  12%|█▏        | 2/17 [00:00<00:01, 11.84it/s, v_num=0]
# Epoch 10:  71%|███████   | 12/17 [00:01<00:00,  9.94it/s, v_num=0]t/s]
# Epoch 11:  18%|█▊        | 3/17 [00:00<00:01, 11.47it/s, v_num=0]it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 28.08it/s]
# Epoch 10: 100%|██████████| 17/17 [00:01<00:00, 10.45it/s, v_num=0]
# Epoch 11:  47%|████▋     | 8/17 [00:00<00:00, 12.24it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 11:  29%|██▉       | 5/17 [00:00<00:00, 12.04it/s, v_num=0]
# Epoch 11:  35%|███▌      | 6/17 [00:00<00:00, 12.60it/s, v_num=0]it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 18.39it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 25.43it/s]
# Epoch 11: 100%|██████████| 17/17 [00:01<00:00, 12.33it/s, v_num=0]
# Epoch 11:  82%|████████▏ | 14/17 [00:01<00:00, 12.61it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 11:  88%|████████▊ | 15/17 [00:01<00:00, 12.82it/s, v_num=0]t/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 30.70it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 39.29it/s]
# Epoch 11: 100%|██████████| 17/17 [00:01<00:00, 13.13it/s, v_num=0]
# Epoch 11:  53%|█████▎    | 9/17 [00:00<00:00, 11.12it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 12:  12%|█▏        | 2/17 [00:00<00:01, 12.28it/s, v_num=0]it/s]
# Epoch 11:  59%|█████▉    | 10/17 [00:00<00:00, 11.26it/s, v_num=0]t/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 34.74it/s]
# Epoch 11: 100%|██████████| 17/17 [00:01<00:00, 11.30it/s, v_num=0]
# Epoch 12:  53%|█████▎    | 9/17 [00:00<00:00, 10.73it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 12:  41%|████      | 7/17 [00:00<00:00, 11.17it/s, v_num=0]
# Epoch 12:  59%|█████▉    | 10/17 [00:00<00:00, 11.19it/s, v_num=0]t/s]
# Epoch 12:  47%|████▋     | 8/17 [00:00<00:00, 11.66it/s, v_num=0]it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 34.84it/s]
# Epoch 12: 100%|██████████| 17/17 [00:01<00:00, 12.03it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 12:  35%|███▌      | 6/17 [00:00<00:00, 11.35it/s, v_num=0]
# Epoch 12:  41%|████      | 7/17 [00:00<00:00, 11.58it/s, v_num=0]]t/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 17.27it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 23.58it/s]
# Epoch 12: 100%|██████████| 17/17 [00:01<00:00, 10.65it/s, v_num=0]
# 2025-07-13 09:23:14,282 - InProcessClientAPI - INFO - Try to send local model back to peer
# Epoch 12: 100%|██████████| 17/17 [00:01<00:00, 12.11it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 12:  53%|█████▎    | 9/17 [00:00<00:00, 12.04it/s, v_num=0]1it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 47.48it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 47.80it/s]
# Epoch 12:  88%|████████▊ | 15/17 [00:01<00:00, 13.49it/s, v_num=0]2025-07-13 09:23:14,755 - ClientRunner - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=4c1d65fd-75f6-4fcd-9201-229811deb787]: finished processing task
# 2025-07-13 09:23:14,756 - ClientRunner - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=4c1d65fd-75f6-4fcd-9201-229811deb787]: try #1: sending task result to server
# 2025-07-13 09:23:14,757 - ClientRunner - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=4c1d65fd-75f6-4fcd-9201-229811deb787]: checking task ...
# Epoch 13:  29%|██▉       | 5/17 [00:00<00:00, 16.27it/s, v_num=0]2025-07-13 09:23:14,758 - Cell - INFO - broadcast: channel='aux_communication', topic='__task_check__', targets=['server.simulate_job'], timeout=5.0
# 2025-07-13 09:23:14,773 - ClientRunner - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=4c1d65fd-75f6-4fcd-9201-229811deb787]: start to send task result to server
# 2025-07-13 09:23:14,774 - FederatedClient - INFO - Starting to push execute result.
# 2025-07-13 09:23:14,794 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_3, peer_run=simulate_job]: got result from client site_3 for task: name=train, id=4c1d65fd-75f6-4fcd-9201-229811deb787
# Epoch 13:  65%|██████▍   | 11/17 [00:00<00:00, 17.28it/s, v_num=0]2025-07-13 09:23:15,112 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_3, peer_run=simulate_job, peer_rc=OK, task_name=train, task_id=4c1d65fd-75f6-4fcd-9201-229811deb787]: finished processing client result by controller
# 2025-07-13 09:23:15,114 - SubmitUpdateCommand - INFO - submit_update process. client_name:site_3   task_id:4c1d65fd-75f6-4fcd-9201-229811deb787
# 2025-07-13 09:23:15,119 - Communicator - INFO -  SubmitUpdate size: 36.2KB (36191 Bytes). time: 0.344372 seconds
# 2025-07-13 09:23:15,120 - ClientRunner - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=4c1d65fd-75f6-4fcd-9201-229811deb787]: task result sent to server
# 2025-07-13 09:23:15,121 - ClientTaskWorker - INFO - Finished one task run for client: site_3 interval: 2 task_processed: True
# Epoch 12: 100%|██████████| 17/17 [00:01<00:00, 11.36it/s, v_num=0]
# Epoch 13:  71%|███████   | 12/17 [00:00<00:00, 17.21it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch 13:  76%|███████▋  | 13/17 [00:00<00:00, 17.26it/s, v_num=0]t/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 36.94it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 47.69it/s]
# Epoch 13: 100%|██████████| 17/17 [00:00<00:00, 17.59it/s, v_num=0]
# Epoch 13:  18%|█▊        | 3/17 [00:00<00:00, 16.45it/s, v_num=0]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# ...
# 2025-07-13 09:23:47,450 - ClientRunner - INFO - [identity=site_2, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=272a2f36-1336-4de7-93ae-113920f54c9b]: start to send task result to server
# 2025-07-13 09:23:47,450 - Communicator - INFO -  SubmitUpdate size: 36.2KB (36191 Bytes). time: 0.290977 seconds
# 2025-07-13 09:23:47,450 - FederatedClient - INFO - Starting to push execute result.
# 2025-07-13 09:23:47,450 - ClientRunner - INFO - [identity=site_1, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=816456db-7ecb-4e40-ad50-9e5270e294d5]: task result sent to server
# 2025-07-13 09:23:47,451 - ClientTaskWorker - INFO - Finished one task run for client: site_1 interval: 2 task_processed: True
# 2025-07-13 09:23:47,461 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_2, peer_run=simulate_job]: got result from client site_2 for task: name=train, id=272a2f36-1336-4de7-93ae-113920f54c9b
# 2025-07-13 09:23:47,463 - IntimeModelSelector - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_2, peer_run=simulate_job, peer_rc=OK, task_name=train, task_id=272a2f36-1336-4de7-93ae-113920f54c9b]: validation metric 0.7748446464538574 from client site_2
# 2025-07-13 09:23:47,563 - nvflare.app_common.executors.task_script_runner - INFO -
# [Current Round=4, Site = site_3]
#
# 2025-07-13 09:23:47,564 - nvflare.app_common.executors.task_script_runner - INFO - --- validate global model ---
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 55.28it/s]
# 2025-07-13 09:23:47,680 - nvflare.app_common.executors.task_script_runner - INFO - ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#      Validate metric           DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         val_loss            0.7633442282676697
# ──────────────────────────────────���─────────────────────────────────────────────────────────────────────────────────────
# 2025-07-13 09:23:47,684 - nvflare.app_common.executors.task_script_runner - INFO - --- train new model ---
# 2025-07-13 09:23:47,733 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_2, peer_run=simulate_job, peer_rc=OK, task_name=train, task_id=272a2f36-1336-4de7-93ae-113920f54c9b]: finished processing client result by controller
# 2025-07-13 09:23:47,734 - SubmitUpdateCommand - INFO - submit_update process. client_name:site_2   task_id:272a2f36-1336-4de7-93ae-113920f54c9b
# 2025-07-13 09:23:47,738 - Communicator - INFO -  SubmitUpdate size: 36.2KB (36191 Bytes). time: 0.287836 seconds
# 2025-07-13 09:23:47,739 - ClientRunner - INFO - [identity=site_2, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=272a2f36-1336-4de7-93ae-113920f54c9b]: task result sent to server
# 2025-07-13 09:23:47,740 - ClientTaskWorker - INFO - Finished one task run for client: site_2 interval: 2 task_processed: True
# 2025-07-13 09:23:47,784 - lightning.pytorch.callbacks.model_summary - INFO -
#   | Name  | Type   | Params | Mode
# -----------------------------------------
# 0 | model | DeepNN | 7.6 K  | train
# -----------------------------------------
# 7.6 K     Trainable params
# 0         Non-trainable params
# 7.6 K     Total params
# 0.030     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# 2025-07-13 09:23:47,786 - RestoreState - INFO - optimizer states restored.
# Epoch 26:   6%|▌         | 1/17 [00:00<00:00, 19.88it/s, v_num=0]
# INFO:
#   | Name  | Type   | Params | Mode
# -----------------------------------------
# 0 | model | DeepNN | 7.6 K  | train
# -----------------------------------------
# 7.6 K     Trainable params
# 0         Non-trainable params
# 7.6 K     Total params
# 0.030     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# Epoch 26: 100%|██████████| 17/17 [00:00<00:00, 20.02it/s, v_num=0]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/3 [00:00<?, ?it/s]
# Validation DataLoader 0:  33%|███▎      | 1/3 [00:00<00:00, 80.05it/s]
# Validation DataLoader 0:  67%|██████▋   | 2/3 [00:00<00:00, 43.63it/s]
# Validation DataLoader 0: 100%|██████████| 3/3 [00:00<00:00, 55.52it/s]
# Epoch 26: 100%|██████████| 17/17 [00:00<00:00, 17.82it/s, v_num=0]
# 2025-07-13 09:23:48,749 - InProcessClientAPI - INFO - Try to send local model back to peer
# 2025-07-13 09:23:49,157 - ClientRunner - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=72bcc029-2cf8-4830-bc18-b5c7c8a00e09]: finished processing task
# 2025-07-13 09:23:49,158 - ClientRunner - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=72bcc029-2cf8-4830-bc18-b5c7c8a00e09]: try #1: sending task result to server
# 2025-07-13 09:23:49,159 - ClientRunner - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=72bcc029-2cf8-4830-bc18-b5c7c8a00e09]: checking task ...
# 2025-07-13 09:23:49,159 - Cell - INFO - broadcast: channel='aux_communication', topic='__task_check__', targets=['server.simulate_job'], timeout=5.0
# 2025-07-13 09:23:49,168 - ClientRunner - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=72bcc029-2cf8-4830-bc18-b5c7c8a00e09]: start to send task result to server
# 2025-07-13 09:23:49,169 - FederatedClient - INFO - Starting to push execute result.
# 2025-07-13 09:23:49,180 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_3, peer_run=simulate_job]: got result from client site_3 for task: name=train, id=72bcc029-2cf8-4830-bc18-b5c7c8a00e09
# 2025-07-13 09:23:49,182 - IntimeModelSelector - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_3, peer_run=simulate_job, peer_rc=OK, task_name=train, task_id=72bcc029-2cf8-4830-bc18-b5c7c8a00e09]: validation metric 0.7633442282676697 from client site_3
# 2025-07-13 09:23:49,457 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_3, peer_run=simulate_job, peer_rc=OK, task_name=train, task_id=72bcc029-2cf8-4830-bc18-b5c7c8a00e09]: finished processing client result by controller
# 2025-07-13 09:23:49,458 - WFCommServer - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: task train exit with status TaskCompletionStatus.OK
# 2025-07-13 09:23:49,462 - SubmitUpdateCommand - INFO - submit_update process. client_name:site_3   task_id:72bcc029-2cf8-4830-bc18-b5c7c8a00e09
# 2025-07-13 09:23:49,469 - Communicator - INFO -  SubmitUpdate size: 36.2KB (36191 Bytes). time: 0.300205 seconds
# 2025-07-13 09:23:49,470 - ClientRunner - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job, task_name=train, task_id=72bcc029-2cf8-4830-bc18-b5c7c8a00e09]: task result sent to server
# 2025-07-13 09:23:49,471 - ClientTaskWorker - INFO - Finished one task run for client: site_3 interval: 2 task_processed: True
# 2025-07-13 09:23:49,657 - IntimeModelSelector - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_3, peer_run=simulate_job, peer_rc=OK, task_name=train, task_id=72bcc029-2cf8-4830-bc18-b5c7c8a00e09]: new best validation metric at round 4: 0.772425651550293
# 2025-07-13 09:23:49,664 - FedAvg - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_3, peer_run=simulate_job, peer_rc=OK, task_name=train, task_id=72bcc029-2cf8-4830-bc18-b5c7c8a00e09]: aggregating 3 update(s) at round 4
# 2025-07-13 09:23:49,666 - FedAvg - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_3, peer_run=simulate_job, peer_rc=OK, task_name=train, task_id=72bcc029-2cf8-4830-bc18-b5c7c8a00e09]: Start persist model on server.
# 2025-07-13 09:23:49,671 - FedAvg - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_3, peer_run=simulate_job, peer_rc=OK, task_name=train, task_id=72bcc029-2cf8-4830-bc18-b5c7c8a00e09]: End persist model on server.
# 2025-07-13 09:23:49,672 - FedAvg - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_3, peer_run=simulate_job, peer_rc=OK, task_name=train, task_id=72bcc029-2cf8-4830-bc18-b5c7c8a00e09]: Finished FedAvg.
# 2025-07-13 09:23:49,672 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: Workflow: controller finalizing ...
# 2025-07-13 09:23:49,673 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: ABOUT_TO_END_RUN fired
# 2025-07-13 09:23:49,679 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: Firing CHECK_END_RUN_READINESS ...
# 2025-07-13 09:23:49,681 - ClientRunner - INFO - [identity=site_1, run=simulate_job, peer=simulator_server, peer_run=simulate_job]: received request from Server to end current RUN
# 2025-07-13 09:23:49,683 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: END_RUN fired
# 2025-07-13 09:23:49,683 - ClientRunner - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job]: received request from Server to end current RUN
# 2025-07-13 09:23:49,683 - ReliableMessage - INFO - ReliableMessage is shutdown
# 2025-07-13 09:23:49,683 - ClientRunner - INFO - [identity=site_2, run=simulate_job, peer=simulator_server, peer_run=simulate_job]: received request from Server to end current RUN
# 2025-07-13 09:23:49,683 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: Server runner finished.
# 2025-07-13 09:23:49,748 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_2, peer_run=simulate_job]: server runner is finalizing - asked client to end the run
# 2025-07-13 09:23:49,748 - GetTaskCommand - INFO - return task to client.  client_name: site_2  task_name: __end_run__   task_id:   sharable_header_task_id:
# 2025-07-13 09:23:49,751 - ReliableMessage - INFO - shutdown reliable message monitor
# 2025-07-13 09:23:49,752 - FederatedClient - INFO - pull_task completed. Task name:__end_run__ Status:True
# 2025-07-13 09:23:49,752 - ClientRunner - INFO - [identity=site_2, run=simulate_job, peer=simulator_server, peer_run=simulate_job]: server asked to end the run
# 2025-07-13 09:23:49,753 - ClientRunner - INFO - [identity=site_2, run=simulate_job]: started end-run events sequence
# 2025-07-13 09:23:49,753 - ClientRunner - INFO - [identity=site_2, run=simulate_job]: ABOUT_TO_END_RUN fired
# 2025-07-13 09:23:49,754 - ClientRunner - INFO - [identity=site_2, run=simulate_job]: Firing CHECK_END_RUN_READINESS ...
# 2025-07-13 09:23:49,755 - InProcessClientAPI - WARNING - ask to stop job: reason: END_RUN received
# 2025-07-13 09:23:49,971 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_1, peer_run=simulate_job]: server runner is finalizing - asked client to end the run
# 2025-07-13 09:23:49,972 - GetTaskCommand - INFO - return task to client.  client_name: site_1  task_name: __end_run__   task_id:   sharable_header_task_id:
# 2025-07-13 09:23:49,975 - FederatedClient - INFO - pull_task completed. Task name:__end_run__ Status:True
# 2025-07-13 09:23:49,976 - ClientRunner - INFO - [identity=site_1, run=simulate_job, peer=simulator_server, peer_run=simulate_job]: server asked to end the run
# 2025-07-13 09:23:49,976 - ClientRunner - INFO - [identity=site_1, run=simulate_job]: started end-run events sequence
# 2025-07-13 09:23:49,977 - ClientRunner - INFO - [identity=site_1, run=simulate_job]: ABOUT_TO_END_RUN fired
# 2025-07-13 09:23:49,977 - ClientRunner - INFO - [identity=site_1, run=simulate_job]: Firing CHECK_END_RUN_READINESS ...
# 2025-07-13 09:23:49,978 - InProcessClientAPI - WARNING - ask to stop job: reason: END_RUN received
# 2025-07-13 09:23:50,042 - InProcessClientAPI - WARNING - request to stop the job for reason END_RUN received
# 2025-07-13 09:23:50,044 - ClientRunner - INFO - [identity=site_1, run=simulate_job]: END_RUN fired
# 2025-07-13 09:23:50,044 - ClientTaskWorker - INFO - End the Simulator run.
# 2025-07-13 09:23:50,056 - SimulatorServer - INFO - Server app stopped.
#
#
# 2025-07-13 09:23:50,086 - ClientTaskWorker - INFO - Clean up ClientRunner for : site_1
# 2025-07-13 09:23:50,089 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connection [CN00007 Not Connected] is closed PID: 545801
# 2025-07-13 09:23:50,090 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connection [CN00002 Not Connected] is closed PID: 545870
# 2025-07-13 09:23:50,192 - InProcessClientAPI - WARNING - request to stop the job for reason END_RUN received
# 2025-07-13 09:23:50,193 - ClientRunner - INFO - [identity=site_2, run=simulate_job]: END_RUN fired
# 2025-07-13 09:23:50,194 - ClientTaskWorker - INFO - End the Simulator run.
# 2025-07-13 09:23:50,236 - ClientTaskWorker - INFO - Clean up ClientRunner for : site_2
# 2025-07-13 09:23:50,239 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connection [CN00006 Not Connected] is closed PID: 545801
# 2025-07-13 09:23:50,240 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connection [CN00002 Not Connected] is closed PID: 545871
# 2025-07-13 09:23:50,458 - nvflare.fuel.hci.server.hci - INFO - Admin Server localhost on Port 33733 shutdown!
# 2025-07-13 09:23:50,459 - SimulatorServer - INFO - shutting down server
# 2025-07-13 09:23:50,459 - SimulatorServer - INFO - canceling sync locks
# 2025-07-13 09:23:50,459 - SimulatorServer - INFO - server off
# 2025-07-13 09:23:51,479 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller, peer=site_3, peer_run=simulate_job]: server runner is finalizing - asked client to end the run
# 2025-07-13 09:23:51,480 - GetTaskCommand - INFO - return task to client.  client_name: site_3  task_name: __end_run__   task_id:   sharable_header_task_id:
# 2025-07-13 09:23:51,483 - FederatedClient - INFO - pull_task completed. Task name:__end_run__ Status:True
# 2025-07-13 09:23:51,484 - ClientRunner - INFO - [identity=site_3, run=simulate_job, peer=simulator_server, peer_run=simulate_job]: server asked to end the run
# 2025-07-13 09:23:51,484 - ClientRunner - INFO - [identity=site_3, run=simulate_job]: started end-run events sequence
# 2025-07-13 09:23:51,485 - ClientRunner - INFO - [identity=site_3, run=simulate_job]: ABOUT_TO_END_RUN fired
# 2025-07-13 09:23:51,486 - ClientRunner - INFO - [identity=site_3, run=simulate_job]: Firing CHECK_END_RUN_READINESS ...
# 2025-07-13 09:23:51,487 - InProcessClientAPI - WARNING - ask to stop job: reason: END_RUN received
# 2025-07-13 09:23:51,766 - InProcessClientAPI - WARNING - request to stop the job for reason END_RUN received
# 2025-07-13 09:23:51,768 - ClientRunner - INFO - [identity=site_3, run=simulate_job]: END_RUN fired
# 2025-07-13 09:23:51,768 - ClientTaskWorker - INFO - End the Simulator run.
# 2025-07-13 09:23:51,810 - ClientTaskWorker - INFO - Clean up ClientRunner for : site_3
# 2025-07-13 09:23:51,810 - FederatedClient - INFO - Shutting down client run: site_1
# 2025-07-13 09:23:51,811 - FederatedClient - INFO - Shutting down client run: site_2
# 2025-07-13 09:23:51,812 - FederatedClient - INFO - Shutting down client run: site_3
# 2025-07-13 09:23:51,814 - ServerRunner - INFO - [identity=simulator_server, run=simulate_job, wf=controller]: asked to abort - triggered abort_signal to stop the RUN
# 2025-07-13 09:23:51,815 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connection [CN00008 Not Connected] is closed PID: 545801
# 2025-07-13 09:23:51,815 - nvflare.fuel.f3.sfm.conn_manager - INFO - Connection [CN00002 Not Connected] is closed PID: 545872
# 2025-07-13 09:23:55,465 - MPM - INFO - MPM: Good Bye!
